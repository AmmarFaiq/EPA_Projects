# %%
import pandas as pd
import numpy as np

# %%
Demo = pd.read_excel('kwb-2017_preped.xls')

# %%
Demo = Demo.dropna(axis=1, how='all')

# %%
Gemeente = Demo.loc[Demo['recs']== 'Gemeente']

# %% [markdown]
# Rename the column so we can do the merge

# %%
Gemeente = Gemeente.rename(columns={'gwb_code_8': 'GemeenteCode'})

# %%
Gemeente
# Out:
#       gwb_code_10  GemeenteCode                           regio  \
# 1          GM0003             3                      Appingedam
# 9          GM0005             5                           Bedum
# 19         GM0007             7                    Bellingwedde
# 45         GM0009             9                        Ten Boer
# 60         GM0010            10                        Delfzijl
# 90         GM0014            14                       Groningen
# 214        GM0015            15                      Grootegast
# 235        GM0017            17                           Haren
# 252        GM0018            18             Hoogezand-Sappemeer
# 309        GM0022            22                            Leek
# 342        GM0024            24                       Loppersum
# 370        GM0025            25                           Marum
# 388        GM0034            34                          Almere
# 461        GM0037            37                     Stadskanaal
# ...

# %%
Elections_2017 = pd.read_csv('Gemeente_uitslagen_TK2017.csv')

# %%
Merged = pd.merge(Gemeente, Elections_2017, on = 'GemeenteCode')

# %%
Merged
# Out:
#     gwb_code_10  GemeenteCode                           regio  \
# 0        GM0003             3                      Appingedam
# 1        GM0005             5                           Bedum
# 2        GM0007             7                    Bellingwedde
# 3        GM0009             9                        Ten Boer
# 4        GM0010            10                        Delfzijl
# 5        GM0014            14                       Groningen
# 6        GM0015            15                      Grootegast
# 7        GM0017            17                           Haren
# 8        GM0018            18             Hoogezand-Sappemeer
# 9        GM0022            22                            Leek
# 10       GM0024            24                       Loppersum
# 11       GM0025            25                           Marum
# 12       GM0034            34                          Almere
# 13       GM0037            37                     Stadskanaal
# ...

# %% [markdown]
# Still needs to change the variable types to integer will be uploaded shortly
