# %%
#!/usr/bin/env python
# encoding: utf-8

import tweepy #https://github.com/tweepy/tweepy
import csv

#Twitter API credentials

consumer_key= '0YJQlQtmUf0Y6N7NVu5rA33fk'
consumer_secret= 'bduF2iguZjQSkq6G17jsX0yax9ICOcLWNYUicR99b51GLzeNam'
access_key= '1017116258-GUN3YAWrElxuVDDkeazQui0rhOsuR08UNgIRYg2'
access_secret= 'My6igTJbpw1nHtNwid3P9qksNicScwLxTlGrkFcDuTK53'

def get_all_tweets(screen_name):
    #Twitter only allows access to a users most recent 3240 tweets with this method

    #authorize twitter, initialize tweepy
    auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
    auth.set_access_token(access_key, access_secret)
    api = tweepy.API(auth)

    #initialize a list to hold all the tweepy Tweets
    alltweets = []

    #make initial request for most recent tweets (200 is the maximum allowed count)
    new_tweets = api.user_timeline(screen_name = screen_name,count=200)

    #save most recent tweets
    alltweets.extend(new_tweets)

    #save the id of the oldest tweet less one
    oldest = alltweets[-1].id - 1

    #keep grabbing tweets until there are no tweets left to grab
    while len(new_tweets) > 0:
        print( "getting tweets before %s" % (oldest))

        #all subsiquent requests use the max_id param to prevent duplicates
        new_tweets = api.user_timeline(screen_name = screen_name,count=200,max_id=oldest)

        #save most recent tweets
        alltweets.extend(new_tweets)

        #update the id of the oldest tweet less one
        oldest = alltweets[-1].id - 1

        print( "...%s tweets downloaded so far" % (len(alltweets)))

    #transform the tweepy tweets into a 2D array that will populate the csv	
    outtweets = [[tweet.id_str, tweet.created_at, tweet.text.encode("utf-8")] for tweet in alltweets]

    #write the csv
    with open('%s_tweets.csv' % screen_name, 'w') as f:
        writer = csv.writer(f)
        writer.writerow(["id","created_at","text"])
        writer.writerows(outtweets)

    pass

get_all_tweets("lidwieneik_boom")
# Out:
# getting tweets before 972805534893199359
# ...400 tweets downloaded so far
# getting tweets before 972030645756100608
# ...600 tweets downloaded so far
# getting tweets before 971075309528408063
# ...800 tweets downloaded so far
# getting tweets before 970408433966034943
# ...1000 tweets downloaded so far
# getting tweets before 969472470184091647
# ...1200 tweets downloaded so far
# getting tweets before 968149427318816770
# ...1399 tweets downloaded so far
# getting tweets before 967068075823681536
# ...1599 tweets downloaded so far
# getting tweets before 966320385284366335
# ...1799 tweets downloaded so far
# getting tweets before 965295267338772479
# ...1999 tweets downloaded so far
# getting tweets before 964522632417865727
# ...2199 tweets downloaded so far
# getting tweets before 963300111630643199
# ...2399 tweets downloaded so far
# getting tweets before 962714396534460416
# ...2599 tweets downloaded so far
# getting tweets before 961616643632775168
# ...2799 tweets downloaded so far
# getting tweets before 960529057174704128
# ...2999 tweets downloaded so far
# getting tweets before 959175859314847743
# ...3198 tweets downloaded so far
# getting tweets before 958343091450273796
# ...3221 tweets downloaded so far
# getting tweets before 958052607226007551
# ...3221 tweets downloaded so far

# %%
# import tweepy
# import time
# #insert your Twitter keys here

# twitter_handle='Leonvangalen99'

# consumer_key= '0YJQlQtmUf0Y6N7NVu5rA33fk'
# consumer_secret= 'bduF2iguZjQSkq6G17jsX0yax9ICOcLWNYUicR99b51GLzeNam'
# access_key= '1017116258-GUN3YAWrElxuVDDkeazQui0rhOsuR08UNgIRYg2'
# access_secret= 'My6igTJbpw1nHtNwid3P9qksNicScwLxTlGrkFcDuTK53'

# auth = tweepy.auth.OAuthHandler(consumer_key, consumer_secret)
# auth.set_access_token(access_key, access_secret)
# api = tweepy.API(auth)

# list= open('twitter_followers.txt','w')

# if(api.verify_credentials):
#     print('We successfully logged in')

# user = tweepy.Cursor(api.followers, screen_name=twitter_handle).items()

# while True:
#     try:
#         u = next(user)
#         list.write(u.screen_name +' \n')

#     except:
#         time.sleep(15*60)
#         print ('We got a timeout ... Sleeping for 15 minutes')
#         u = next(user)
#         list.write(u.screen_name +' \n')
# list.close()
