# %% [markdown]
# # Imports

# %%
# adapting
# https://www.machinelearningplus.com/nlp/topic-modeling-python-sklearn-examples/

# %%
# !pip install pyLDAvis

# %%
import numpy as np
import pandas as pd
import re, nltk, spacy, gensim

# Sklearn
from sklearn.decomposition import LatentDirichletAllocation, TruncatedSVD
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from sklearn.model_selection import GridSearchCV
from pprint import pprint

# Plotting tools
import pyLDAvis
import pyLDAvis.sklearn
import matplotlib.pyplot as plt
# %matplotlib inline
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\manifold\t_sne.py:420: DeprecationWarning: invalid escape sequence \s
#   """

# %% [markdown]
# # Data Loading

# %%
# create a list of words
from os import listdir
from os.path import isfile, join

# alter this path to your local environment
mypath = '.data/vaccination/'
onlyfiles = [f for f in listdir(mypath) if isfile(join(mypath, f))]
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-7-a903bab97dd3> in <module>()
#       5 # alter this path to your local environment
#       6 mypath = '.data/vaccination/'
# ----> 7 onlyfiles = [f for f in listdir(mypath) if isfile(join(mypath, f))]
#
# FileNotFoundError: [WinError 3] The system cannot find the path specified: '.data/vaccination/'

# %%
import json
all_tweets = []

for f in onlyfiles:
    full_name = mypath+'/'+f

    with open(full_name, 'r') as f:
        data = json.load(f)
        all_tweets.extend(data)

# %%
text_dict = {} 
text_list = []
id_list = []
for tweet in all_tweets:
    if ('text' in tweet.keys()):
        if ('id' in tweet.keys()):
            my_id = tweet['id']
            if (tweet['text'] != None):

                text_dict[my_id] = tweet['text']
                id_list.append(my_id)
                text_list.append([tweet['text']])
            
t = len(text_dict)

# %%
print(text_list[1])
# Out:
# ['RT @Zecca_Lehn: RECREATING THE VACCINE HEATMAP IN PLOTLY 4.0+ WITH R @RobertMitchellV #rstats https://t.co/ttiusFP4Vu']

# %% [markdown]
# # Tweet Processing with Gensim

# %%
def sent_to_words(sentences):
    for sentence in sentences:
        yield(gensim.utils.simple_preprocess(str(sentence), deacc=True))  # deacc=True removes punctuations

data_words = list(sent_to_words(text_list))

# %%
# perhaps the user names need to be handled
print(data_words[2])
# Out:
# ['rt', 'it', 'is', 'time', 'to', 'drain', 'the', 'swamp', 'npetition', 'to', 'be', 'signed', 'nneed', 'if', 'you', 'care', 'share', 'nto', 'stop', 'autism', 'epidemic']

# %%
def lemmatization(texts, allowed_postags=['NOUN', 'ADJ', 'VERB', 'ADV']):
    """https://spacy.io/api/annotation"""
    texts_out = []
    for sent in texts:
        doc = nlp(" ".join(sent)) 
        texts_out.append(" ".join([token.lemma_ if token.lemma_ not in ['-PRON-'] else '' for token in doc if token.pos_ in allowed_postags]))
    return texts_out

# Initialize spacy 'en' model, keeping only tagger component (for efficiency)
# Run in terminal: python3 -m spacy download en
nlp = spacy.load('en', disable=['parser', 'ner'])

# Do lemmatization keeping only Noun, Adj, Verb, Adverb
data_lemmatized = lemmatization(data_words, allowed_postags=['NOUN', 'ADJ', 'VERB', 'ADV'])

print(data_lemmatized[:2])
# Out:
# ['lovehoesright swinger party atl hiv vaccination trial', 'zecca_lehn recreate vaccine heatmap plotly robertmitchellv rstat https co ttiusfp vu']

# %%
print(data_words[:2])
print(data_lemmatized[:2])
# Out:
# [['rt', 'lovehoesright', 'swinger', 'party', 'in', 'atl', 'hiv', 'vaccination', 'trial'], ['rt', 'zecca_lehn', 'recreating', 'the', 'vaccine', 'heatmap', 'in', 'plotly', 'with', 'robertmitchellv', 'rstats', 'https', 'co', 'ttiusfp', 'vu']]
# ['lovehoesright swinger party atl hiv vaccination trial', 'zecca_lehn recreate vaccine heatmap plotly robertmitchellv rstat https co ttiusfp vu']

# %%
vectorizer = CountVectorizer(analyzer='word',       
                             min_df=10,                        # minimum reqd occurences of a word 
                             stop_words='english',             # remove stop words
                             lowercase=True,                   # convert all words to lowercase
                             token_pattern='[a-zA-Z0-9]{3,}',  # num chars > 3
                             # max_features=50000,             # max number of uniq words
                            )

data_vectorized = vectorizer.fit_transform(data_lemmatized)

# %%
# Materialize the sparse data
data_dense = data_vectorized.todense()

# Compute Sparsicity = Percentage of Non-Zero cells
print("Sparsicity: ", ((data_dense > 0).sum()/data_dense.size)*100, "%")
# Out:
# Sparsicity:  0.145982187552 %

# %% [markdown]
# # Topic Modeling with LDA

# %%
topics = 10
# Build LDA Model
lda_model = LatentDirichletAllocation(n_topics=topics,               # Number of topics
                                      max_iter=20,               # Max learning iterations
                                      learning_method='online',   
                                      random_state=100,          # Random state
                                      batch_size=128,            # n docs in each learning iter
                                      evaluate_every = -1,       # compute perplexity every n iters, default: Don't
                                      n_jobs = -1,               # Use all available CPUs
                                     )
lda_output = lda_model.fit_transform(data_vectorized)

print(lda_model)  # Model attributes
# Out:
# C:\Users\LocalAdmin\Anaconda3\lib\site-packages\sklearn\decomposition\online_lda.py:294: DeprecationWarning: n_topics has been renamed to n_components in version 0.19 and will be removed in 0.21
#   DeprecationWarning)

# %%
# Log Likelihood: Higher the better
print("Log Likelihood: ", lda_model.score(data_vectorized))

# Perplexity: Lower the better. Perplexity = exp(-1. * log-likelihood per word)
print("Perplexity: ", lda_model.perplexity(data_vectorized))

# See model parameters
pprint(lda_model.get_params())

# %%
best_lda_model = lda_model
data=text_list

# %%
# Create Document - Topic Matrix
lda_output = best_lda_model.transform(data_vectorized)

# column names
topicnames = ["Topic" + str(i+1) for i in range(topics)]

# index names
docnames = ["Doc" + str(i) for i in range(len(data))]

# %%
# Make the pandas dataframe
df_document_topic = pd.DataFrame(np.round(lda_output, 2), columns=topicnames, index=id_list)

# Get dominant topic for each document
dominant_topic = np.argmax(df_document_topic.values, axis=1)
df_document_topic['dominant_topic'] = dominant_topic+1


# Styling
def color_green(val):
    color = 'green' if val > .1 else 'black'
    return 'color: {col}'.format(col=color)

def make_bold(val):
    weight = 700 if val > .1 else 400
    return 'font-weight: {weight}'.format(weight=weight)

# Apply Style
df_document_topics = df_document_topic.head(15).style.applymap(color_green).applymap(make_bold)
df_document_topics
# Out:
# <style  type="text/css" >
#     #T_9885bf80_6422_11e8_88ca_9cb6d0e9dd62row0_col0 {
#             color:  black;
#             font-weight:  400;
#         }    #T_9885bf80_6422_11e8_88ca_9cb6d0e9dd62row0_col1 {
#             color:  black;
#             font-weight:  400;
#         }    #T_9885bf80_6422_11e8_88ca_9cb6d0e9dd62row0_col2 {
#             color:  green;
#             font-weight:  700;
#         }    #T_9885bf80_6422_11e8_88ca_9cb6d0e9dd62row0_col3 {
#             color:  black;
#             font-weight:  400;
#         }    #T_9885bf80_6422_11e8_88ca_9cb6d0e9dd62row0_col4 {
#             color:  black;
#             font-weight:  400;
#         }    #T_9885bf80_6422_11e8_88ca_9cb6d0e9dd62row0_col5 {
#             color:  black;
#             font-weight:  400;
#         }    #T_9885bf80_6422_11e8_88ca_9cb6d0e9dd62row0_col6 {
#             color:  black;
#             font-weight:  400;
#         }    #T_9885bf80_6422_11e8_88ca_9cb6d0e9dd62row0_col7 {
#             color:  black;
#             font-weight:  400;
#         }    #T_9885bf80_6422_11e8_88ca_9cb6d0e9dd62row0_col8 {
#             color:  black;
#             font-weight:  400;
#         }    #T_9885bf80_6422_11e8_88ca_9cb6d0e9dd62row0_col9 {
#             color:  green;
#             font-weight:  700;
#         }    #T_9885bf80_6422_11e8_88ca_9cb6d0e9dd62row0_col10 {
#             color:  green;
#             font-weight:  700;
#         }    #T_9885bf80_6422_11e8_88ca_9cb6d0e9dd62row1_col0 {
#             color:  black;
#             font-weight:  400;
#         }    #T_9885bf80_6422_11e8_88ca_9cb6d0e9dd62row1_col1 {
#             color:  black;
#             font-weight:  400;
#         }    #T_9885bf80_6422_11e8_88ca_9cb6d0e9dd62row1_col2 {
#             color:  black;
#             font-weight:  400;
#         }    #T_9885bf80_6422_11e8_88ca_9cb6d0e9dd62row1_col3 {
#             color:  green;
#             font-weight:  700;
#         }    #T_9885bf80_6422_11e8_88ca_9cb6d0e9dd62row1_col4 {
#             color:  black;
#             font-weight:  400;
#         }    #T_9885bf80_6422_11e8_88ca_9cb6d0e9dd62row1_col5 {
#             color:  black;
#             font-weight:  400;
#         }    #T_9885bf80_6422_11e8_88ca_9cb6d0e9dd62row1_col6 {
#             color:  green;
#             font-weight:  700;
#         }    #T_9885bf80_6422_11e8_88ca_9cb6d0e9dd62row1_col7 {
#             color:  black;
#             font-weight:  400;
#         }    #T_9885bf80_6422_11e8_88ca_9cb6d0e9dd62row1_col8 {
#             color:  black;
#             font-weight:  400;
#         }    #T_9885bf80_6422_11e8_88ca_9cb6d0e9dd62row1_col9 {
#             color:  black;
#             font-weight:  400;
#         }    #T_9885bf80_6422_11e8_88ca_9cb6d0e9dd62row1_col10 {
#             color:  green;
#             font-weight:  700;
#         }    #T_9885bf80_6422_11e8_88ca_9cb6d0e9dd62row2_col0 {
#             color:  black;
#             font-weight:  400;
#         }    #T_9885bf80_6422_11e8_88ca_9cb6d0e9dd62row2_col1 {
#             color:  black;
#             font-weight:  400;
#         }    #T_9885bf80_6422_11e8_88ca_9cb6d0e9dd62row2_col2 {
#             color:  black;
#             font-weight:  400;
#         }    #T_9885bf80_6422_11e8_88ca_9cb6d0e9dd62row2_col3 {
#             color:  green;
#             font-weight:  700;
#         }    #T_9885bf80_6422_11e8_88ca_9cb6d0e9dd62row2_col4 {
#             color:  black;
#             font-weight:  400;
#         }    #T_9885bf80_6422_11e8_88ca_9cb6d0e9dd62row2_col5 {
#             color:  green;
#             font-weight:  700;
#         }    #T_9885bf80_6422_11e8_88ca_9cb6d0e9dd62row2_col6 {
#             color:  black;
#             font-weight:  400;
#         }    #T_9885bf80_6422_11e8_88ca_9cb6d0e9dd62row2_col7 {
#             color:  black;
#             font-weight:  400;
#         }    #T_9885bf80_6422_11e8_88ca_9cb6d0e9dd62row2_col8 {
#             color:  black;
#             font-weight:  400;
#         }    #T_9885bf80_6422_11e8_88ca_9cb6d0e9dd62row2_col9 {
#             color:  black;
#             font-weight:  400;
#         }    #T_9885bf80_6422_11e8_88ca_9cb6d0e9dd62row2_col10 {
#             color:  green;
#             font-weight:  700;
#         }    #T_9885bf80_6422_11e8_88ca_9cb6d0e9dd62row3_col0 {
#             color:  black;
#             font-weight:  400;
#         }    #T_9885bf80_6422_11e8_88ca_9cb6d0e9dd62row3_col1 {
#             color:  green;
#             font-weight:  700;
#         }    #T_9885bf80_6422_11e8_88ca_9cb6d0e9dd62row3_col2 {
#             color:  black;
#             font-weight:  400;
#         }    #T_9885bf80_6422_11e8_88ca_9cb6d0e9dd62row3_col3 {
#             color:  black;
#             font-weight:  400;
#         }    #T_9885bf80_6422_11e8_88ca_9cb6d0e9dd62row3_col4 {
#             color:  black;
#             font-weight:  400;
#         }    #T_9885bf80_6422_11e8_88ca_9cb6d0e9dd62row3_col5 {
#             color:  black;
#             font-weight:  400;
#         }    #T_9885bf80_6422_11e8_88ca_9cb6d0e9dd62row3_col6 {
#             color:  black;
#             font-weight:  400;
#         }    #T_9885bf80_6422_11e8_88ca_9cb6d0e9dd62row3_col7 {
#             color:  green;
#             font-weight:  700;
#         }    #T_9885bf80_6422_11e8_88ca_9cb6d0e9dd62row3_col8 {
#             color:  green;
#             font-weight:  700;
#         }    #T_9885bf80_6422_11e8_88ca_9cb6d0e9dd62row3_col9 {
#             color:  black;
#             font-weight:  400;
#         }    #T_9885bf80_6422_11e8_88ca_9cb6d0e9dd62row3_col10 {
#             color:  green;
#             font-weight:  700;
#         }    #T_9885bf80_6422_11e8_88ca_9cb6d0e9dd62row4_col0 {
#             color:  black;
#             font-weight:  400;
#         }    #T_9885bf80_6422_11e8_88ca_9cb6d0e9dd62row4_col1 {
#             color:  black;
#             font-weight:  400;
#         }    #T_9885bf80_6422_11e8_88ca_9cb6d0e9dd62row4_col2 {
#             color:  black;
#             font-weight:  400;
#         }    #T_9885bf80_6422_11e8_88ca_9cb6d0e9dd62row4_col3 {
#             color:  green;
#             font-weight:  700;
#         }    #T_9885bf80_6422_11e8_88ca_9cb6d0e9dd62row4_col4 {
#             color:  black;
#             font-weight:  400;
#         }    #T_9885bf80_6422_11e8_88ca_9cb6d0e9dd62row4_col5 {
#             color:  black;
#             font-weight:  400;
#         }    #T_9885bf80_6422_11e8_88ca_9cb6d0e9dd62row4_col6 {
#             color:  black;
#             font-weight:  400;
#         }    #T_9885bf80_6422_11e8_88ca_9cb6d0e9dd62row4_col7 {
#             color:  black;
#             font-weight:  400;
#         }    #T_9885bf80_6422_11e8_88ca_9cb6d0e9dd62row4_col8 {
#             color:  green;
#             font-weight:  700;
#         }    #T_9885bf80_6422_11e8_88ca_9cb6d0e9dd62row4_col9 {
#             color:  black;
#             font-weight:  400;
#         }    #T_9885bf80_6422_11e8_88ca_9cb6d0e9dd62row4_col10 {
#             color:  green;
#             font-weight:  700;
#         }    #T_9885bf80_6422_11e8_88ca_9cb6d0e9dd62row5_col0 {
#             color:  green;
#             font-weight:  700;
#         }    #T_9885bf80_6422_11e8_88ca_9cb6d0e9dd62row5_col1 {
#             color:  black;
#             font-weight:  400;
#         }    #T_9885bf80_6422_11e8_88ca_9cb6d0e9dd62row5_col2 {
#             color:  black;
#             font-weight:  400;
#         }    #T_9885bf80_6422_11e8_88ca_9cb6d0e9dd62row5_col3 {
#             color:  black;
#             font-weight:  400;
#         }    #T_9885bf80_6422_11e8_88ca_9cb6d0e9dd62row5_col4 {
#             color:  green;
#             font-weight:  700;
#         }    #T_9885bf80_6422_11e8_88ca_9cb6d0e9dd62row5_col5 {
#             color:  black;
#             font-weight:  400;
#         }    #T_9885bf80_6422_11e8_88ca_9cb6d0e9dd62row5_col6 {
#             color:  black;
#             font-weight:  400;
#         }    #T_9885bf80_6422_11e8_88ca_9cb6d0e9dd62row5_col7 {
#             color:  black;
#             font-weight:  400;
#         }    #T_9885bf80_6422_11e8_88ca_9cb6d0e9dd62row5_col8 {
#             color:  black;
#             font-weight:  400;
#         }    #T_9885bf80_6422_11e8_88ca_9cb6d0e9dd62row5_col9 {
#             color:  black;
#             font-weight:  400;
#         }    #T_9885bf80_6422_11e8_88ca_9cb6d0e9

# %%
relate=df_document_topic.T.dot(df_document_topic)
#relate_ = relate.values[0:13,0:13]
relate = relate.values[0:topics,0:topics]
p = (2)**-2
print(p)
relate_ = np.log(relate**p+1)
plt.imshow(relate_,cmap="hot")
plt.show()
# Out:
# 0.25

# %%
print(relate)
# Out:
# [[ 1992.2575   529.9962   441.7737   466.5837   446.7127   405.4637
#     466.0628   626.0904   503.7529   422.6389]
#  [  529.9962  2987.0696   621.6265   510.2012   541.9192   517.3075
#     673.3562   811.6664   780.6849   434.837 ]
#  [  441.7737   621.6265  1893.9032   486.7423   399.8409   395.7154
#     576.5224   584.1483   517.6187   354.8238]
#  [  466.5837   510.2012   486.7423  2039.2804   443.0206   396.5948
#     595.1124   579.2956   569.0108   300.5394]
#  [  446.7127   541.9192   399.8409   443.0206  1860.1375   385.5664
#     452.7818   577.895    558.6018   368.6802]
#  [  405.4637   517.3075   395.7154   396.5948   385.5664  2097.9633
#     433.4282   538.8574   454.3884   290.2051]
#  [  466.0628   673.3562   576.5224   595.1124   452.7818   433.4282
#    2316.2204   641.6095   570.7486   366.3341]
#  [  626.0904   811.6664   584.1483   579.2956   577.895    538.8574
#     641.6095  3235.9068   707.0717   451.9119]
#  [  503.7529   780.6849   517.6187   569.0108   558.6018   454.3884
#     570.7486   707.0717  2558.0046   435.9649]
#  [  422.6389   434.837    354.8238   300.5394   368.6802   290.2051
#     366.3341   451.9119   435.9649  1592.9369]]

# %%
import seaborn as sns
sns.set(color_codes=True)

g = sns.clustermap(relate_)

# %% [markdown]
# # Visualization with pyLDA

# %%
pyLDAvis.enable_notebook()
panel = pyLDAvis.sklearn.prepare(best_lda_model, data_vectorized, vectorizer, mds='tsne')
panel
# Out:
# PreparedData(topic_coordinates=            Freq  cluster  topics           x           y
# topic
# 1      13.096739        1       1 -433.476959  378.058838
# 7      12.451886        1       2 -169.463730  -25.064833
# 8      11.638364        1       3 -364.076630 -466.738098
# 6      10.530901        1       4  653.536499   41.566113
# 3       9.452708        1       5  482.538696 -397.523560
# 2       9.426435        1       6  218.684464    6.640102
# 0       8.936350        1       7 -604.207703  -61.297653
# 4       8.714112        1       8  413.664978  447.308838
# 5       8.386104        1       9   60.283459 -445.071472
# 9       7.366401        1      10  -11.089329  427.215942, topic_info=     Category          Freq           Term         Total  loglift  logprob
# term
# 5423  Default  26024.000000        vaccine  26024.000000  30.0000  30.0000
# 220   Default   4110.000000           anti   4110.000000  29.0000  29.0000
# 5420  Default  13408.000000    vaccination  13408.000000  28.0000  28.0000
# 1149  Default   3137.000000          death   3137.000000  27.0000  27.0000
# 5457  Default   4260.000000            vax   4260.000000  26.0000  26.0000
# 766   Default   6800.000000          child   6800.000000  25.0000  25.0000
# 3870  Default   3331.000000          polio   3331.000000  24.0000  24.0000
# 3373  Default   4220.000000         nhttps   4220.000000  23.0000  23.0000
# 353   Default   2108.000000         autism   2108.000000  22.0000  22.0000
# 5743  Default   2388.000000           year   2388.000000  21.0000  21.0000
# 3717  Default   2858.000000        pauline   2858.000000  20.0000  20.0000
# 2131  Default   3074.000000         health   3074.000000  19.0000  19.0000
# 2104  Default   3536.000000         hanson   3536.000000  18.0000  18.0000
# 1318  Topic10    253.836381       disgrace    254.727393   2.6047  -5.1410
# 5336  Topic10    252.385249     uneducated    253.276256   2.6047  -5.1467
# 760   Topic10    245.135226            chi    246.026244   2.6046  -5.1758
# 5420  Topic10   3927.645993    vaccination  13408.484158   1.3804  -2.4019
# 3717  Topic10   1341.334434        pauline   2858.588074   1.8516  -3.4762
# 2104  Topic10   1278.088552         hanson   3536.234007   1.5905  -3.5245
# 2260  Topic10   2522.174017          https  44505.592926  -0.2623  -2.8448
#
# [412 rows x 6 columns], token_table=      Topic      Freq          Term
# term
# 32        7  0.996164        accept
# 36        6  0.998106        accord
# 48        9  0.921169        action
# 48       10  0.075469        action
# 57        5  0.997955      actually
# 76        4  0.996935         admit
# 80        9  0.999280         adult
# 89        5  0.995593      advocate
# 107       4  0.997595       african
# 112       3  0.997743           age
# 128       3  0.999049           aid
# 132       5  0.996929           air
# 133       7  0.996285  airpollution
# 153       7  0.998074        algore
# 160       8  0.995720       allergy
# 177      10  0.998394  amapresident
# 188       4  0.999216      american
# 193       1  0.237235           amp
# 193       3  0.132262           amp
# 193       4  0.353305           amp
# 193       6  0.073499           amp
# 193       7  0.203578           amp
# 220       5  0.999777          anti
# 229       4  0.999147       antivax
# 242       3  0.998612      apologis
# 286       6  0.996980       article
# 296       1  0.997776           ask
# 303       5  0.998728     aspiesmom
# 345       8  0.999020        auspol
# 349       7  0.997037     australia
# ...     ...       ...           ...
# 5423      6  0.009914       vaccine
# 5423      8  0.010644       vaccine
# 5423      9  0.147132       vaccine
# 5432      3  0.999633  vaccineswork
# 5457      5  0.818900           vax
# 5457      8  0.180726           vax
# 5463      1  0.247248          vaxx
# 5463      6  0.752174          vaxx
# 5464      2  0.998828        vaxxed
# 5466      5  0.998402        vaxxer
# 5477      4  0.996547  veritasdolor
# 5493      1  0.997883         video
# 5509     10  0.999433         virus
# 5551      7  0.997728          walk
# 5555      7  0.999281          want
# 5568      4  0.996421          wasn
# 5571      1  0.998779         watch
# 5577      3  0.999009           way
# 5584      5  0.998386       wealthy
# 5594      8  0.998334          week
# 5650      4  0.996425           win
# 5650      7  0.002328           win
# 5674      8  0.998375         woman
# 5684      4  0.998878          work
# 5689      6  0.118116         world
# 5689      7  0.880756         world
# 5708      3  0.999057         wrong
# 5743      3  0.999596          year
# 5754      2  0.996948         young
# 5779      8  0.995898          zika
#
# [416 rows x 3 columns], R=30, lambda_step=0.01, plot_opts={'xlab': 'PC1', 'ylab': 'PC2'}, topic_order=[2, 8, 9, 7, 4, 3, 1, 5, 6, 10])

# %%
output_dict = {}
output = df_document_topic.values

m,n = output.shape

for i in range(m):
    row=output[i]

    output_dict[id_list[i]]=list(output[i])

# %%
import json

with open('tweet_topics10.json', 'w') as fp:
    json.dump(output_dict, fp)

# %%
df_topic_distribution = df_document_topic['dominant_topic'].value_counts().reset_index(name="Num Documents")
df_topic_distribution.columns = ['Topic Num', 'Num Documents']
df_topic_distribution
# Out:
#    Topic Num  Num Documents
# 0          8           9930
# 1          2           8895
# 2          9           7015
# 3          7           6973
# 4          4           6767
# 5          1           6394
# 6          3           6308
# 7          5           5499
# 8          6           5452
# 9         10           4275
