# %% [markdown]
# ### Gensim LDA

# %%
import re, os, time
import numpy as np
import pandas as pd
from pprint import pprint

# Gensim
from gensim.models.ldamodel import LdaModel
from gensim.models import Phrases
from gensim.models.phrases import Phraser
import gensim.corpora as corpora
from gensim.utils import simple_preprocess
from gensim.models import CoherenceModel

# Import nltk stopwords and spacy for lemmatization
from nltk.corpus import stopwords
from nltk.tokenize import WordPunctTokenizer

# Plotting tools
import pyLDAvis
import pyLDAvis.gensim  # don't skip this
import matplotlib.pyplot as plt
import spacy
# %matplotlib inline

# Enable logging for Gensim - optional
import logging
logging.basicConfig(format='%(asctime)s : %(levelname)s : %(message)s', level=logging.ERROR)

import warnings
warnings.filterwarnings('ignore',category=DeprecationWarning)

import time

import bs4


# Plotting tools
import pyLDAvis
import pyLDAvis.sklearn
import matplotlib.pyplot as plt
import textacy

from bokeh.charts import Chord

from pysankey import sankey
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\gensim\utils.py:1197: UserWarning: detected Windows; aliasing chunkize to chunkize_serial
#   warnings.warn("detected Windows; aliasing chunkize to chunkize_serial")
# C:\ProgramData\Anaconda3\lib\site-packages\bokeh\util\deprecation.py:34: BokehDeprecationWarning:
# The bokeh.charts API has moved to a separate 'bkcharts' package.
#
# This compatibility shim will remain until Bokeh 1.0 is released.
# After that, if you want to use this API you will have to install
# the bkcharts package explicitly.
#
#   warn(message)

# %%
current_dir = os.getcwd()
os.chdir(current_dir)

# %% [markdown]
# #### 1. Import dataset

# %% [markdown]
# #### Dutch elections dataset

# %% [markdown]
# First of all, we need to load and preprocess the data. All Tweets were collected and stored in _JSON_ (JavaScript Object Notation) format. As reference: "JSON is a lightweight data-interchange format. It is easy for humans to read and write. It is easy for machines to parse and generate.". After loading it, we want to manipulate the data in _lists_ and _dictionaries_. In addition, we will collect statistics about the dataset.

# %%
# Collect names of Tweet files
from os import listdir
from os.path import isfile, join
import pickle
import json
mypath = 'data/election'
onlyfiles = [f for f in listdir(mypath) if isfile(join(mypath, f))]

# %%
# Collect all Tweets available and store them as list of dicts

all_tweets = []

for f in onlyfiles:
    full_name = mypath+'/'+f

    with open(full_name, 'r') as f:
        data = json.load(f)
        all_tweets.extend(data)

# %%
all_tweets_df = pd.DataFrame(all_tweets)
all_tweets_df = all_tweets_df[all_tweets_df['lang'] == 'nl']

# %%
print('All tweets :',len(all_tweets))

# %%
all_tweets = all_tweets_df.to_dict('records')

# %%
print('All dutch only tweets :',len(all_tweets))

# %%
# Save collected Tweets
with open('elections_tweets', 'w') as fout:
    json.dump(all_tweets, fout)

# %%
# Load collected Tweets
import json
with open('elections_tweets', 'r') as fout:
        all_tweets = json.load(fout)

# %%
# Statistics
print('Sample of a Tweet:', all_tweets[0]['text'], '\n')
print('Number of fields available:', len(all_tweets[0].keys()), '\n')
print('Fields available in a Tweet:', '\n', [*all_tweets[0]], '\n')
print('Info avaialable in the whole set:', '\n', pd.DataFrame(all_tweets[:10]).columns.values)

# %%
# Extract the data (id and text), and put it into dict and list
text_dict = {} 
text_list = []
id_list = []
missing_tweets = 0

for tweet in all_tweets:
    if ('text' in tweet.keys()):
        if ('id' in tweet.keys()):
            my_id = tweet['id']
            if (tweet['text'] != None):
                text_dict[my_id] = tweet['text']
                id_list.append(my_id)
                text_list.append([tweet['text']])
                
            elif (tweet['text'] == None):
                missing_values = missing_tweets + 1

# %%
# Save processed Tweets
with open('elections_text_list', 'wb') as fp:
    pickle.dump(text_list, fp)
    
with open('elections_text_dict', 'wb') as fp:
    pickle.dump(text_dict, fp, protocol=pickle.HIGHEST_PROTOCOL)

# %%
# Load processed Tweets
with open('elections_text_list', 'rb') as fp:
    text_list = pickle.load(fp)
    
with open('elections_text_dict', 'rb') as fp:
    text_dict = pickle.load(fp)

# %%
# Statistics
t = len(text_dict)
max_length = 0
average_length = 0

for tweet in text_list : 
    average_length = average_length + sum(len(i) for i in tweet) 
    if (sum(len(i) for i in tweet) > max_length) : 
        max_length = sum(len(i) for i in tweet)
        max_tweet = tweet

print('In total ' + str(t) + ' Tweets collected')
print('On average Tweet is ' + str(round(average_length / t)) + ' charachters long', '\n')
print('Longest Tweet is:', max_tweet, '\n')
print('It is', sum(len(i) for i in max_tweet), 'characters long')
# Out:
# In total 715155 Tweets collected
# On average Tweet is 126 charachters long
#
# Longest Tweet is: ['RT @RoosjeXS: &amp;#39;Als angst mijn&amp;nbsp;raadgever wordt,&amp;nbsp;dan moet ik&amp;nbsp;meteen iets anders&amp;nbsp;gaan doen.&amp;#39; - Sigrid Kaag https:/…']
#
# It is 164 characters long

# %%
# Let's inspect the Tweets
pd.DataFrame(text_list[:5])
# Out:
#                                                    0
# 0  RT @Derksen_Gelul: Nederlands bekendste droogk...
# 1  RT @GerBStruik: Niet alleen Ollongren, maar ni...
# 2  @JoostNiemoller Joost, trap er toch niet in. H...
# 3  @EenVandaag @thierrybaudet @D66 @APechtold Ald...
# 4  Dolhuysbrug moet na tien jaar definitief van t...

# %% [markdown]
# #### 2. Remove emails and newline characters

# %% [markdown]
# Now it is time to preprocess the Tweets. We will exclude some symbols, links, etc. Thereafter for algorithmic purposes, we need to split each Tweet (a combination of sentences) into a combination of words.

# %%
# Before
pprint(text_list[:3])
# Out:
# [['RT @Derksen_Gelul: Nederlands bekendste droogkloot, Marcel van Roosmalen '
#   'sloopt D66 helemaal de moeder!! Luister zelf naar deze topper en g…'],
#  ['RT @GerBStruik: Niet alleen Ollongren, maar niemand in #Rutte3 heeft '
#   'kennelijk enig benul van staatsrecht. Een minister die als minister ee…'],
#  ['@JoostNiemoller Joost, trap er toch niet in. Hier is één grote minne '
#   'manipulatie aan de gang tegen FVD. Deze heeft… https://t.co/lVFOuFFYF3']]

# %%
def tweet_cleaner(text):
    soup =  bs4.BeautifulSoup(text, 'lxml')
    souped = soup.get_text()
    try:
        bom_removed = souped.decode("utf-8-sig").replace(u"\ufffd", "?")
    except:
        bom_removed = souped
        
    return bom_removed

data = text_list
# data = text_list[-int(1e5):]

# Remove Emails and links to users
data = [re.sub('\S*@\S*\s?', '', str(sent)) for sent in data]

# Remove new line characters
data = [re.sub('\s+', ' ', str(sent)) for sent in data]

# Remove distracting single quotes
data = [re.sub("\'", "", str(sent)) for sent in data]

# Remove https and links
pat1 = r'@[A-Za-z0-9]+'
pat2 = r'https?://[A-Za-z0-9./]+'
combined_pat = r'|'.join((pat1, pat2))

data = [re.sub(combined_pat, "", str(sent)) for sent in data]

data = [re.sub(r"https\S+", "", str(sent)) for sent in data]

data = [re.sub(r"www.[^ ]+", "", str(sent)) for sent in data]


data = [tweet_cleaner(sent) for sent in data]

# %%
# After
pprint(data[:3])
# TODO: take care of \\n
# Out:
# ['[RT Nederlands bekendste droogkloot, Marcel van Roosmalen sloopt D66 '
#  'helemaal de moeder!! Luister zelf naar deze topper en g…]',
#  '[RT Niet alleen Ollongren, maar niemand in #Rutte3 heeft kennelijk enig '
#  'benul van staatsrecht. Een minister die als minister ee…]',
#  'Joost, trap er toch niet in. Hier is één grote minne manipulatie aan de gang '
#  'tegen FVD. Deze heeft… ]']

# %% [markdown]
# #### 3. Tokenize words and Clean-up text

# %%
def sent_to_words(sentences) :
    '''Split sentences into words'''
    for sentence in sentences :
        # The main function here is Gensim's simple_preprocess
        yield(simple_preprocess(str(sentence), deacc=True))  # deacc=True removes punctuations

data_words = list(sent_to_words(data))

# Let's explore what do we have now
pd.DataFrame(data_words[:5])
# Out:
#             0           1          2           3       4           5   \
# 0           rt  nederlands  bekendste  droogkloot  marcel         van
# 1           rt        niet     alleen   ollongren    maar     niemand
# 2        joost        trap         er        toch    niet          in
# 3        aldus   leugenaar        hoe       durft    deze      partij
# 4  dolhuysbrug        moet         na        tien    jaar  definitief
#
#           6       7         8          9       10           11     12  \
# 0  roosmalen  sloopt  helemaal         de  moeder      luister   zelf
# 1         in   rutte     heeft  kennelijk    enig        benul    van
# 2       hier      is       een      grote   minne  manipulatie    aan
# 3        nog      de       van       None    None         None   None
# 4        van   tafel       vvd    haarlem   nmaak           uw  eigen
#
#             13    14        15    16    17        18    19
# 0         naar  deze    topper    en  None      None  None
# 1  staatsrecht   een  minister   die   als  minister    ee
# 2           de  gang     tegen   fvd  deze     heeft  None
# 3         None  None      None  None  None      None  None
# 4       filter   ove      None  None  None      None  None

# %% [markdown]
# #### 4. Remove Stopwords, Make Bigrams and Lemmatize

# %% [markdown]
# Here we're continuing to preprocess the Tweets by excluding so-called stopwords - just a set of common used words such as 'and', 'so', etc. in English. NLTK package has a collections of stopwords for Dutch language as well. Also, we can extend the set by adding words that should be considered as redundant ones.

# %%
# NLTK stop words collection
stop_words = stopwords.words('dutch')

# TODO: Extend stop words collection using native speaker knowledge
# stop_words.extend(['from', 'subject', 're', 'edu', 'use'])
stop_words.extend(['rt', 'htt', 'via'])

# %%
print('The number of Dutch stop words avaialable:', len(stop_words), '\n')
print(stop_words)
# Out:
# The number of Dutch stop words avaialable: 104
#
# ['de', 'en', 'van', 'ik', 'te', 'dat', 'die', 'in', 'een', 'hij', 'het', 'niet', 'zijn', 'is', 'was', 'op', 'aan', 'met', 'als', 'voor', 'had', 'er', 'maar', 'om', 'hem', 'dan', 'zou', 'of', 'wat', 'mijn', 'men', 'dit', 'zo', 'door', 'over', 'ze', 'zich', 'bij', 'ook', 'tot', 'je', 'mij', 'uit', 'der', 'daar', 'haar', 'naar', 'heb', 'hoe', 'heeft', 'hebben', 'deze', 'u', 'want', 'nog', 'zal', 'me', 'zij', 'nu', 'ge', 'geen', 'omdat', 'iets', 'worden', 'toch', 'al', 'waren', 'veel', 'meer', 'doen', 'toen', 'moet', 'ben', 'zonder', 'kan', 'hun', 'dus', 'alles', 'onder', 'ja', 'eens', 'hier', 'wie', 'werd', 'altijd', 'doch', 'wordt', 'wezen', 'kunnen', 'ons', 'zelf', 'tegen', 'na', 'reeds', 'wil', 'kon', 'niets', 'uw', 'iemand', 'geweest', 'andere', 'rt', 'htt', 'via']

# %% [markdown]
# Thereafter, we need to identify combinations of words that frequently appear together. For these purposes, we need to create so-called 'bigrams ' and 'trigrams'. Bigrams are two words frequently occurring together in the document. Trigrams are 3 words frequently occurring.

# %%
# Build the bigram and trigram models

# One of the most important parameters here is min_count 
# If set up, for example, as 5, then only those bigrams and trigrams will be stored that appear 5 times or more

# Threshold is 
# TODO: set up various parameters for min_count and threshold
start = time.time()
bigram = Phrases(data_words, min_count=5, threshold=10) 
trigram = Phrases(bigram[data_words], threshold=10)  

# Faster way to get a sentence clubbed as a trigram/bigram
bigram_mod = Phraser(bigram)
trigram_mod = Phraser(trigram)
end = time.time()
print('Algorithm time =', round((end-start)/60), 'min')

# See trigram example
print(trigram_mod[bigram_mod[data_words[5]]])
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\gensim\models\phrases.py:494: UserWarning: For a faster implementation, use the gensim.models.phrases.Phraser class
#   warnings.warn("For a faster implementation, use the gensim.models.phrases.Phraser class")
# Algorithm time = 1 min
# ['rt', 'niet', 'alleen', 'ollongren', 'maar', 'niemand', 'in', 'rutte', 'heeft_kennelijk_enig', 'benul', 'van', 'staatsrecht', 'een', 'minister', 'die', 'als', 'minister', 'ee']

# %% [markdown]
# Lemmatization is converting a word to its root word. Spacy NLP package responsible for that. Thanks we have Dutch language version.

# %%
# Define functions for stopwords, bigrams, trigrams and lemmatization
def remove_stopwords(texts) :
    return [[word for word in simple_preprocess(str(doc)) if word not in stop_words] for doc in texts]

def make_bigrams(texts) :
    return [bigram_mod[doc] for doc in texts]

def make_trigrams(texts) :
    return [trigram_mod[bigram_mod[doc]] for doc in texts]

def lemmatization(texts, allowed_postags=['NOUN', 'ADJ', 'VERB', 'ADV']) :
    texts_out = []
    for sent in texts :
        doc = nlp(" ".join(sent)) 
        texts_out.append([token.lemma_ for token in doc if token.pos_ in allowed_postags])
    return texts_out

# %%
# Remove stop words
start = time.time()
data_words_nostops = remove_stopwords(data_words)

# Form bigrams
data_words_bigrams = make_bigrams(data_words_nostops)

nlp = spacy.load('nl', disable=['parser', 'ner'])

# Do lemmatization keeping only noun, adj, vb, adv
data_lemmatized = lemmatization(data_words_bigrams, allowed_postags=['NOUN', 'ADJ', 'VERB', 'ADV'])

end = time.time()

# %%
print('Algorithm time =', round((end-start)/60), 'min')
print(data_words[:1])
print(data_words_nostops[:1])
print(data_words_bigrams[:1])
print(data_lemmatized[:1])
# Out:
# Algorithm time = 27 min
# [['rt', 'nederlands', 'bekendste', 'droogkloot', 'marcel', 'van', 'roosmalen', 'sloopt', 'helemaal', 'de', 'moeder', 'luister', 'zelf', 'naar', 'deze', 'topper', 'en']]
# [['nederlands', 'bekendste', 'droogkloot', 'marcel', 'roosmalen', 'sloopt', 'helemaal', 'moeder', 'luister', 'topper']]
# [['nederlands_bekendste', 'droogkloot_marcel', 'roosmalen_sloopt', 'helemaal', 'moeder_luister', 'topper']]
# [['nederlands_bekendste', 'droogkloot_marcel', 'roosmalen_sloopt', 'helemaal', 'moeder_luister', 'topper']]

# %%
len(data_lemmatized)
# Out:
# 715668

# %%
data_lemmatized
# Out:
# [['nederlands_bekendste',
#   'droogkloot_marcel',
#   'roosmalen_sloopt',
#   'helemaal',
#   'moeder_luister',
#   'topper'],
#  ['alleen',
#   'ollongren',
#   'rutte',
#   'kennelijk_enig',
#   'benul',
#   'staatsrecht',
#   'minister',
#   'minister',
#   'ee'],
#  ['joost', 'trap', 'grote_minne', 'manipulatie', 'gang', 'fvd'],
#  ['aldus', 'leugenaar', 'durft', 'partij'],
#  ['dolhuysbrug',
#   'tien_jaar',
#   'definitief',
#   'tafel',
#   'vvd',
#   'haarlem_nmaak',
#   'eigen_filter'],
#  ['alleen',
#   'ollongren',
#   'rutte',
#   'kennelijk_enig',
#   'benul',
#   'staatsrecht',
#   'minister',
#   'minister',
#   'ee'],
#  ['gemeente', 'geeft', 'geheim', 'kiezer', 'afgerekend_ton'],
#  ['rutte', 'vvd', 'steunt', 'rutte', 'neemt', 'maat', 'racis'],
#  ['maarten',
#   'jan',
#   'staat',
#   'nummer',
#   'kandidatenlijst',
#   'gelooft',
#   'talenten',
#   'ontwik'],
#  ['compleet_kafka',
#   'nrutte',
#   'vvd',
#   'ollongren',
#   'vinden',
#   'baudet',
#   'fvd',
#   'geobsedeerd',
#   'praten',
#   'rassen'],
#  ['maart',
#   'mag',
#   'stemmen',
#   'sleepwet',
#   'stemadvies',
#   'duidelijk',
#   'ngroenlinks',
#   'sleepwet'],
#  ['zorgelijk_vind',
#   'keer',
#   'keer',
#   'suggestie_wekt',
#   'mensen',
#   'partij',
#   'verd'],
#  ['heel',
#   'mooi_nieuws',
#   'juf_ank',
#   'leraren',
#   'kabinet',
#   'begint',
#   'verlagen',
#   'werkdruk_strijdt',
#   'jaren'],
#  ['opvalt', 'msm', 'racisme', 'sporen', 'anti', 'racisten_openlijk', 'rac'],
#  ['suddeutsche', 'zeitung', 'artikel', 'baudet', 'racisme', 'gaat', 'nergens'],
#  ['alleen',
#   'ollongren',
#   'rutte',
#   'kennelijk_enig',
#   'benul',
#   'staatsrecht',
#   'minister',
#   'minister',
#   'ee'],
#  ['alleen',
#   'ollongren',
#   'rutte',
#   'kennelijk_enig',
#   'benul',
#   'staatsrecht',
#   'minister',
#   'minister',
#   'ee'],
#  ['walgelijk',
#   'voornemen',
#   'minister',
#   'kabinet',
#   'pakt',
#   'meest_kwetsbaren',
#   'gaat',
#   'onverdroten'],
#  ['heel',
#   'mooi_nieuws',
#   'werkdrukakkoord_tussen',
#   'onderwijsveld',
#   'jaar',
#   'scholen',
#   'vruchten'],
#  ['heel',
#   'mooi_nieuws',
#   'juf_ank',
#   'leraren',
#   'kabinet',
#   'begint',
#   'verlagen',
#   'werkdruk_strijdt',
#   'jaren'],
#  ['heel',
#   'mooi_nieuws',
#   'juf_ank',
#   'leraren',
#   'kabinet',
#   'begint',
#   'verlagen',
#   'werkdruk_strijdt',
#   'jaren'],
#  ['alleen',
#   'ollongren',
#   'rutte',
#   'kennelijk_enig',
#   'benul',
#   'staatsrecht',
#   'minister',
#   'minister',
#   'ee'],
#  ['vraag', 'punt', 'bijdrage', 'gemeente', 'voorst', 'vanuit'],
#  ['opvalt', 'msm', 'racisme', 'sporen', 'anti', 'racisten_openlijk', 'rac'],
#  ['mensen_realiseren', 'totaal', 'europa', 'eurotransplant'],
#  ['aanwezig',
#   'gaat',
#   'meelopen',
#   'mars',
#   'racisme',
#   'wel',
#   'eerder',
#   'hoorde'],
#  ['jesse_klaver',
#   'vindt',
#   'anti',
#   'racisme',
#   'demo',
#   'prima',
#   'lilian_marijnissen',
#   'vindt',
#   'adam',
#   'vvd',
#   'mag',
#   'samenwerken'],
#  ['regering', 'jaren', 'nek_omgedraaid', 'tekort', 'goud', 'handw'],
#  ['mensen_realiseren',
#   'totaal',
#   'organen_uitgevent',
#   'europa',
#   'eurotransplant_doet',
#   'voo'],
#  ['vice_premier',
#   'hugo',
#   'jonge',
#   'speech',
#   'ollongren',
#   'waar',
#   'achter',
#   'kunt',
#   'staan'],
#  ['alleen',
#   'ollongren',
#   'rutte',
#   'kennelijk_enig',
#   'benul',
#   'staatsrecht',
#   'minister',
#   'minister',
#   'ee'],
#  ['heel',
#   'mooi_nieuws',
#   'juf_ank',
#   'leraren',
#   'kabinet',
#   'begint',
#   'verlagen',
#   'werkdruk_strijdt',
#   'jaren'],
#  ['eerst_herindelen',
#   'luchtruim',
#   'hogere_vliegroutes',
#   'ontzien',
#   'woonkernen',
#   'daarna',
#   'ka'],
#  ['mensen_realiseren',
#   'totaal',
#   'organen_uitgevent',
#   'europa',
#   'eurotransplant_doet',
#   'voo'],
#  ['hierbij', 'steun', 'omroep', 'laat', 'groen', 'collegas', 'vrij'],
#  ['ah', 'zegt', 'lokaal', 'willen', 'samenwerking'],
#  ['aldus', 'leugenaar', 'durft', 'partij', 'democratie'],
#  ['onderwijsdebat',
#   'gemist',
#   'jammer',
#   'superpitch',
#   'gelijke_kansen',
#   'onderwijs',
#   'wel'],
#  ['heel',
#   'mooi_nieuws',
#   'werkdrukakkoord_tussen',
#   'onderwijsveld',
#   'jaar',
#   'scholen',
#   'vruchten'],
#  ['weer', 'liegen', 'wel'],
#  ['alleen',
#   'ollongren',
#   'rutte',
#   'kennelijk_enig',
#   'benul',
#   'staatsrecht',
#   'minister',
#   'minister',
#   'ee'],
#  ['alleen',
#   'ollongren',
#   'rutte',
#   'kennelijk_enig',
#   'benul',
#   'staatsrecht',
#   'minister',
#   'minister',
#   'ee'],
#  ['patrick',
#   'schie_directeur',
#   'telderstichting_vvd',
#   'nten_diepste',
#   'onliberaal_vindt',
#   'schie',
#   'donorwet'],
#  ['merijnvanas', 'stemd'],
#  ['aanwezig',
#   'gaat',
#   'meelopen',
#   'mars',
#   'racisme',
#   'wel',
#   'eerder',
#   'hoorde',
#   'ongem'],
#  ['heel',
#   'mooi_nieuws',
#   'juf_ank',
#   'leraren',
#   'kabinet',
#   'begint',
#   'verlagen',
#   'werkdruk_strijdt',
#   'jaren'],
#  ['gekkie'],
#  ['hele', 'debat', 'zonde', 'energie', 'tijd', 'geld', 'tering'],
#  ['patrick',
#   'schie_directeur',
#   'telderstichting_vvd',
#   'nten_diepste',
#   'onliberaal_vindt',
#   'schie',
#   'donorwet',
#   'eerst'],
#  ['alleen',
#   'ollongren',
#   'rutte',
#   'kennelijk_enig',
#   'benul',
#   'staatsrecht',
#   'minister',
#   'minister',
#   'ee'],
#  ['alleen',
#   'ollongren',
#   'rutte',
#   'kennelijk_enig',
#   'benul',
#   'staatsrecht',
#   'minister',
#   'minister',
#   'ee'],
#  ['snappen', 'waarom', 'afdeling', 'communicatie', 'schiedam', 'zoek'],
#  ['mensen_realiseren',
#   'totaal',
#   'organen_uitgevent',
#   'europa',
#   'eurotransplant_doet',
#   'voo'],
#  ['net',
#   'uitschrijving',
#   'ontvangen',
#   'snapt',
#   'democratie',
#   'vrijheden',
#   'keuzes',
#   'nhet'],
#  ['hey', 'ras', 'discriminatie', 'zegt'],
#  ['narcist', 'wel', 'zin', 'woorden', 'zeggen', 'woord', 'racisme'],
#  ['bah', 'prinsje', 'frame', 'racisme', 'fvd', 'gooien', 'hekel', 'zelfinge'],
#  ['uitspraken', 'ras', 'iq_volmaakt', 'idioot', 'reactie', 'cda'],
#  ['compleet_kafka',
#   'nrutte',
#   'vvd',
#   'ollongren',
#   'vinden',
#   'baudet',
#   'fvd',
#   'geobsedeerd',
#   'praten',
#   'rassen'],
#  ['opnieuw',
#   'uiterst_merkwaardig',
#   'dubbelspel',
#   'groenlinkser_liesbeth',
#   'tongeren',
#   'waarom',
#   'maakte',
#   'groningse'],
#  ['fijn',
#   'enthousiasme',
#   'groen',
#   'delen',
#   'mag',
#   'naam',
#   'groene',
#   'stembusakkoo'],
#  ['wel', 'artikeltje', 'nepnieuws', 'agenda'],
#  ['groenlinks',
#   'eist_duidelijkheid',
#   'extra',
#   'vliegbewegingen',
#   'lelystad_airport',
#   'kamerlid',
#   'suzanne_kroger',
#   'exact',
#   'weten'],
#  ['assen', 'partij', 'onderwijs', 'ondernemers'],
#  ['rutte', 'vvd', 'steunt', 'rutte', 'neemt', 'maat', 'racis'],
#  ['cda',
#   'adam',
#   'zet',
#   'goed',
#   'openbaar_vervoer',
#   'video',
#   'leg',
#   'hoedan',
#   'geld',
#   'topsalarisse'],
#  ['leveamsterdam',
#   'openbaar_vervoer',
#   'ooit',
#   'dachten',
#   'noord_zuidlijn',
#   'kosten'],
#  ['nacht', 'leefbaar_rotterdam', 'nachtvanlr'],
#  ['financien', 'amsterdam', 'verneukt', 'kostte', 'bane'],
#  ['man', 'moment', 'geheim', 'werkt', 'handboek_populisme', 'http'],
#  ['alleen',
#   'ollongren',
#   'rutte',
#   'kennelijk_enig',
#   'benul',
#   'staatsrecht',
#   'minister',
#   'minister',
#   'ee'],
#  ['rotterdam', 'doet', 'baudet', 'alliantie', 'leefbaar_rotterdam'],
#  ['nacht', 'leefbaar_rotterdam', 'nachtvanlr'],
#  ['kabinet',
#   'verhoogt',
#   'btw',
#   'kaartjes',
#   'openbaar_vervoer',
#   'laten',
#   'zorgen'],
#  ['alleen',
#   'ollongren',
#   'rutte',
#   'kennelijk_enig',
#   'benul',
#   'staatsrecht',
#   'minister',
#   'minister',
#   'ee'],
#  ['man',
#   'amsterdam',
#   'bekrachtigd',
#   'grote',
#   'onzin',
#   'lelystad_airport',
#   'gaat',
#   'vlucht',
#   'anderhalf_uur',
#   'leugen'],
#  ['los',
#   'morgen',
#   'rotterdam_ontwaken',
#   'leefbaar_rotterdam',
#   'nachtvanlr',
#   'gr'],
#  ['partijkartel', 'helemaal', 'open_discussie', 'partijkartel', 'lynchpartij'],
#  ['alleen',
#   'ollongren',
#   'rutte',
#   'kennelijk_enig',
#   'benul',
#   'staatsrecht',
#   'minister',
#   'minister',
#   'ee'],
#  ['heren', 'heren', 'waarom', 'gewoon', 'tafel', 'gesprek', 'wijzen', 'ndus'],
#  ['zie',
#   'voorstanders',
#   'nieuwe',
#   'donorwet',
#   'kiezersgroep',
#   'kiezers',
#   'vvd',
#   'pvda'],
#  ['leider',
#   'kabinet',
#   'amsterdam',
#   'helpen',
#   'btw',
#   'verhogen',
#   'kaartjes',
#   'openb'],
#  ['regering',
#   'vuile',
#   'rutte',
#   'elende',
#   'veroorzaakt',
#   'veroorzaakt',
#   'haat'],
#  ['patrick',
#   'schie_directeur',
#   'telderstichting_vvd',
#   'nten_diepste',
#   'onliberaal_vindt',
#   'schie',
#   'donorwet',
#   'eerst'],
#  ['kralingen_crooswijk', 'kleurt_groen', 'hulp', 'next', 'next_generation'],
#  ['leider',
#   'kabinet',
#   'amsterdam',
#   'helpen',
#   'btw',
#   'verhogen',
#   'kaartjes',
#   'openbaar_vervoer'],
#  ['fipronil',
#   'vervuilde',
#   'mest',
#   'aangelengd',
#   'schone',
#   'mest',
#   'uitrijden',
#   'land',
#   'verhoudt',
#   'onlangs',
#   'on'],
#  ['leider',
#   'kabinet',
#   'amsterdam',
#   'helpen',
#   'btw',
#   'verhogen',
#   'kaartjes',
#   'openbaar_vervoer'],
#  ['kabinet',
#   'verhoogt',
#   'btw',
#   'kaartjes',
#   'openbaar_vervoer',
#   'laten',
#   'zorgen',
#   'amste'],
#  ['leveamsterdam',
#   'openbaar_vervoer',
#   'ooit',
#   'dachten',
#   'noord_zuidlijn',
#   'kosten'],
#  ['landelijk',
#   'amsterdam',
#   'jesse_klaver',
#   'groen_links',
#   'moeten',
#   'busverbindingen',
#   'komen',
#   'au'],
#  ['landelijk',
#   'amsterdam',
#   'jesse_klaver',
#   'groen_links',
#   'moeten',
#   'busverbindingen',
#   'komen',
#   'auto',
#   'minde'],
#  ['lekker', 'lokaal', 'partij', 'gbt', 'komt', 'elke_kern', 'verder', 'mee'],
#  ['openbaar_vervoer',
#   'snel',
#   'betaalbaar',
#   'sp_knokt',
#   'behoud',
#   'metrolijnen_terwijl',
#   'kabinet'],
#  ['weren',
#   'amsterdamse',
#   'binnenstad',
#   'leefbaar',
#   'houden',
#   'amsterdamkiest_leveams'],
#  ['openbaar_vervoer',
#   'snel',
#   'betaalbaar',
#   'sp_knokt',
#   'behoud',
#   'metrolijnen_terwijl',
#   'kabinet',
#   'btw',
#   'kaartje'],
#  ['ah_vertrekt', 'zei', 'racistische', 'club', 'zei_studentikoos'],
#  ['weren',
#   'amsterdamse',
#   'binnenstad',
#   'leefbaar',
#   'houden',
#   'amsterdamkiest_leveams'],
#  ['openbaar_vervoer',
#   'snel',
#   'betaalbaar',
#   'sp_knokt',
#   'behoud',
#   'metrolijnen_terwijl',
#   'kabinet',
#   'btw',
#   'kaartje'],
#  ['weren',
#   'amsterdamse',
#   'binnenstad',
#   'leefbaar',
#   'houden',
#   'amsterdamkiest_leveams'],
#  ['mensen_realiseren',
#   'totaal',
#   'organen_uitgevent',
#   'europa',
#   'eurotransplant_doet',
#   'voo'],
#  ['weer', 'bezuiniging', 'bijna_procent', 'groepen', 'kabinet', 'vvd', 'cda'],
#  ['weren',
#   'amsterdamse',
#   'binnenstad',
#   'leefbaar',
#   'houden',
#   'amsterdamkiest_leveams'],
#  ['alleen',
#   'ollongren',
#   'rutte',
#   'kennelijk_enig',
#   'benul',
#   'staatsrecht',
#   'minister',
#   'minister',
#   'ee'],
#  ['nieuws', 'knvb', 'geeft', 'kivuvu', 'groen', 'licht', 'dovo'],
#  ['zonnepanelen_plan',
#   'gratis_stroom',
#   'gemeente',
#   'amsterdam',
#   'kost_honderden'],
#  ['patrick',
#   'schie_directeur',
#   'telderstichting_vvd',
#   'nten_diepste',
#   'onliberaal_vindt',
#   'schie',
#   'donorwet',
#   'eerst'],
#  ['patrick',
#   'schie_directeur',
#   'telderstichting_vvd',
#   'nten_diepste',
#   'onliberaal_vindt',
#   'schie',
#   'donorwet',
#   'eerst'],
#  ['baudet',
#   'klaver',
#   'tegenover_elkaar',
#   'schiphol',
#   'blijven_groeien',
#   'zegt',
#   'belangrijkste'],
#  ['strafbaar',
#   'strijd',
#   'art_gw',
#   'vwb',
#   'ras',
#   'vwb',
#   'politieke',
#   'gezindh'],
#  ['klaver',
#   'schiphol',
#   'mag',
#   'verder',
#   'groeien',
#   'lelystad_airport',
#   'mag',
#   'open',
#   'gaan',
#   'helder',
#   'gr'],
#  ['baudet',
#   'klaver',
#   'tegenover_elkaar',
#   'schiphol',
#   'blijven_groeien',
#   'zegt',
#   'belangrijkste',
#   'peilers'],
#  ['partijkartel', 'helemaal', 'open_discussie', 'partijkartel', 'lynchpartij'],
#  ['alleen',
#   'ollongren',
#   'rutte',
#   'kennelijk_enig',
#   'benul',
#   'staatsrecht',
#   'minister',
#   'minister',
#   'ee'],
#  ['openbaar_vervoer',
#   'belangrijk',
#   'stad',
#   'bereikbaar',
#   'houden',
#   'hekelt',
#   'terecht',
#   'btw_verhoging'],
#  ['baudet',
#   'klaver',
#   'tegenover_elkaar',
#   'schiphol',
#   'blijven_groeien',
#   'zegt',
#   'belangrijkste',
#   'peilers'],
#  ['kijkt', 'beste', 'mensen', 'korte', 'krachtige', 'uitspraak', 'fake_news'],
#  ['openbaar_vervoer',
#   'snel',
#   'betaalbaar',
#   'sp_knokt',
#   'behoud',
#   'metrolijnen_terwijl',
#   'kabinet',
#   'btw',
#   'kaartje'],
#  ['man', 'moment', 'geheim', 'werkt', 'handboek_populisme', 'http'],
#  ['mooi',
#   'nederlands',
#   'gezegde',
#   'waar',
#   'rook',
#   'vuur',
#   'stinkt',
#   'racisme'],
#  ['leider',
#   'kabinet',
#   'amsterdam',
#   'helpen',
#   'btw',
#   'verhogen',
#   'kaartjes',
#   'openbaar_vervoer'],
#  ['kabinet',
#   'verhoogt',
#   'btw',
#   'kaartjes',
#   'openbaar_vervoer',
#   'laten',
#   'zorgen',
#   'amste'],
#  ['tegenzin', 'geef', 'vvd', 'gelijk'],
#  ['patrick',
#   'schie_directeur',
#   'telderstichting_vvd',
#   'nten_diepste',
#   'onliberaal_vindt',
#   'schie',
#   'donorwet',
#   'eerst'],
#  ['vandaag', 'prima', 'leefbaar'],
#  ['begrijp', 'gemeente', 'pvda', 'fvd', 'landelijke', 'parti'],
#  ['openbaar_vervoer',
#   'snel',
#   'betaalbaar',
#   'sp_knokt',
#   'behoud',
#   'metrolijnen_terwijl',
#   'kabinet',
#   'btw',
#   'kaartje'],
#  ['patrick',
#   'schie_directeur',
#   'telderstichting_vvd',
#   'nten_diepste',
#   'onliberaal_vindt',
#   'schie',
#   'donorwet',
#   'eerst'],
#  ['vandaag', 'prima', 'leefbaar'],
#  ['openbaar_vervoer',
#   'belangrijk',
#   'stad',
#   'bereikbaar',
#   'houden',
#   'hekelt',
#   'terecht',
#   'btw_verhoging',
#   'ka'],
#  ['walgelijk',
#   'voornemen',
#   'minister',
#   'kabinet',
#   'pakt',
#   'meest_kwetsbaren',
#   'gaat',
#   'onverdroten'],
#  ['partijkartel', 'helemaal', 'open_discussie', 'partijkartel', 'lynchpartij'],
#  ['alleen',
#   'ollongren',
#   'rutte',
#   'kennelijk_enig',
#   'benul',
#   'staatsrecht',
#   'minister',
#   'minister',
#   'ee'],
#  ['kijken_marcel',
#   'roosmalen_sloopt',
#   'hypocriet',
#   'donorwet',
#   'penthouse',
#   'pechtold',
#   'helemaal',
#   'gort'],
#  ['voorspelbaar',
#   'racisme',
#   'meme',
#   'komen',
#   'nlinks',
#   'debatteren',
#   'links',
#   'schelden',
#   'leveamste'],
#  ['weg_kwijt', 'zet', 'helemaal', 'gek', 'voornemen', 'flink', 'ove'],
#  ['dorp', 'buurt', 'veilig', 'groen', 'dorps'],
#  ['gedreven', 'persoonlijke_rancune', 'mag', 'journalistiek_bedrijven'],
#  ['voortdurend', 'schiphol', 'goed', 'economie', 'goed', 'mensen', 'aldus'],
#  ['mark',
#   'minpres',
#   'spelen',
#   'korea',
#   'belangrijker',
#   'ramp',
#   'afspeelt',
#   'groningen'],
#  ['jochie', 'links', 'groen', 'lezen', 'leren'],
#  ['alleen',
#   'ollongren',
#   'rutte',
#   'kennelijk_enig',
#   'benul',
#   'staatsrecht',
#   'minister',
#   'minister',
#   'ee'],
#  ['weg_kwijt', 'zet', 'helemaal', 'gek', 'voornemen', 'flink', 'ove'],
#  ['gedreven', 'persoonlijke_rancune', 'mag', 'journalistiek_bedrijven'],
#  ['mark_rutte',
#   'politiek',
#   'leider',
#   'vvd',
#   'laat',
#   'vandaag',
#   'weten',
#   'racisme',
#   'roeper',
#   'ollongren',
#   'staan',
#   'kabinetstan'],
#  ['roept', 'cda', 'orde', 'groenste_kabinet', 'ooit', 'geschapen'],
#  ['kun', 'gewoon', 'bron', 'ophef', 'links', 'vooraan'],
#  ['weren',
#   'amsterdamse',
#   'binnenstad',
#   'leefbaar',
#   'houden',
#   'amsterdamkiest_leveams'],
#  ['duidelijk', 'incidenten'],
#  ['coalitieruzie',
#   'minister',
#   'ollongren',
#   'woordvoerder',
#   'rutte',
#   'pechtold'],
#  ['mark_rutte',
#   'politiek',
#   'leider',
#   'vvd',
#   'laat',
#   'vandaag',
#   'weten',
#   'racisme',
#   'roeper',
#   'ollongren',
#   'staan',
#   'kabinetstan'],
#  ['coalitieruzie',
#   'minister',
#   'ollongren',
#   'woordvoerder',
#   'rutte',
#   'pechtold'],
#  ['gisterenavond',
#   'coryfee',
#   'jan_terlouw',
#   'gast',
#   'gemeente',
#   'nterlouw',
#   'vertelde',
#   'nijverdal'],
#  ['maart',
#   'mag',
#   'stemmen',
#   'sleepwet',
#   'stemadvies',
#   'duidelijk',
#   'ngroenlinks',
#   'sleepwet'],
#  ['man',
#   'lekker_edoch',
#   'eu',
#   'baas',
#   'vvd',
#   'weet',
#   'wel',
#   'eu_lovers',
#   'kabinet'],
#  ['ollongren',
#   'weet',
#   'gewoon',
#   'deint',
#   'laatste',
#   'mode',
#   'nals',
#   'schadeli'],
#  ['gedreven', 'persoonlijke_rancune', 'mag', 'journalistiek_bedrijven'],
#  ['alleen',
#   'ollongren',
#   'rutte',
#   'kennelijk_enig',
#   'benul',
#   'staatsrecht',
#   'minister',
#   'minister',
#   'ee'],
#  ['gedreven', 'persoonlijke_rancune', 'mag', 'journalistiek_bedrijven'],
#  ['nieuws', 'knvb', 'geeft', 'kivuvu', 'groen', 'licht', 'dovo'],
#  ['zie',
#   'nederland',
#   'liever',
#   'rood_wit',
#   'blauw',
#   'kleur',
#   'groen',
#   'doet',
#   'denken',
#   'tijden',
#   'matige',
#   'man'],
#  ['laf',
#   'kleine',
#   'hulp',
#   'behoevende',
#   'groepen',
#   'pakken',
#   'mensen',
#   'zwaar',
#   'moeten',
#   'zwaa'],
#  ['overigens', 'pvda', 'klimaat', 'leveamsterdam'],
#  ['eerlijk',
#   'parijs',
#   'gaat',
#   'halen',
#   'groenste_kabinet',
#   'ooit',
#   'bent',
#   'schiphol',
#   'onde'],
#  ['los',
#   'morgen',
#   'rotterdam_ontwaken',
#   'leefbaar_rotterdam',
#   'nachtvanlr',
#   'gr'],
#  ['gedreven', 'persoonlijke_rancune', 'mag', 'journalistiek_bedrijven'],
#  ['gedreven', 'persoonlijke_rancune', 'mag', 'journalistiek_bedrijven'],
#  ['heel',
#   'mooi_nieuws',
#   'juf_ank',
#   'leraren',
#   'kabinet',
#   'begint',
#   'verlagen',
#   'werkdruk_strijdt',
#   'jaren'],
#  ['gedreven', 'persoonlijke_rancune', 'mag', 'journalistiek_bedrijven'],
#  ['gelukkig_mogelijkheden', 'gekregen_lees', 'structureel', 'technisch_vmbo'],
#  ['gedreven', 'persoonlijke_rancune', 'mag', 'journalistiek_bedrijven'],
#  ['jochie', 'links', 'groen', 'lezen', 'leren'],
#  ['eerlijk',
#   'parijs',
#   'gaat',
#   'halen',
#   'groenste_kabinet',
#   'ooit',
#   'bent',
#   'schiphol',
#   'onde'],
#  ['kamerleden',
#   'voeren',
#   'groot_deel',
#   'dag',
#   'schijndebat',
#   'euro',
#   'prioriteiten'],
#  ['lelystadairport',
#   'word',
#   'gewoon',
#   'weer',
#   'belazerd',
#   'enz',
#   'weet',
#   'stemt',
#   'gr'],
#  ['roept', 'cda', 'orde', 'groenste_kabinet', 'ooit', 'geschapen', 'oneerl'],
#  ['eerlijk',
#   'parijs',
#   'gaat',
#   'halen',
#   'groenste_kabinet',
#   'ooit',
#   'bent',
#   'schiphol',
#   'onde'],
#  ['eerlijk',
#   'parijs',
#   'gaat',
#   'halen',
#   'groenste_kabinet',
#   'ooit',
#   'bent',
#   'schiphol',
#   'onde'],
#  ['rutte', 'vvd', 'steunt', 'rutte', 'neemt', 'maat', 'racis'],
#  ['roept', 'cda', 'orde', 'groenste_kabinet', 'ooit', 'geschapen', 'oneerl'],
#  ['man',
#   'lekker_edoch',
#   'eu',
#   'baas',
#   'vvd',
#   'weet',
#   'wel',
#   'eu_lovers',
#   'kabinet'],
#  ['gedreven', 'persoonlijke_rancune', 'mag', 'journalistiek_bedrijven'],
#  ['zonnepanelen_plan',
#   'gratis_stroom',
#   'gemeente',
#   'amsterdam',
#   'kost_honderden'],
#  ['fascisme', 'racisme', 'bestrijden', 'cpn_beslist', 'gemeen'],
#  ['alleen',
#   'ollongren',
#   'rutte',
#   'kennelijk_enig',
#   'benul',
#   'staatsrecht',
#   'minister',
#   'minister',
#   'ee'],
#  ['heel',
#   'mooi_nieuws',
#   'juf_ank',
#   'leraren',
#   'kabinet',
#   'begint',
#   'verlagen',
#   'werkdruk_strijdt',
#   'jaren'],
#  ['zonnepanelen_plan',
#   'gratis_stroom',
#   'gemeente',
#   'amsterdam',
#   'kost_honderden'],
#  ['komende',
#   'verkiezingen',
#   'pvda',
#   'groenlinks',
#   'lijstnummer',
#   'lokaal',
#   'groen',
#   'sociaal',
#   'lijsten',
#   'cda'],
#  ['heel',
#   'mooi_nieuws',
#   'juf_ank',
#   'leraren',
#   'kabinet',
#   'begint',
#   'verlagen',
#   'werkdruk_strijdt',
#   'jaren'],
#  ['komende',
#   'verkiezingen',
#   'pvda',
#   'groenlinks',
#   'lijstnummer',
#   'lokaal',
#   'groen',
#   'sociaal',
#   'lijsten',
#   'cda'],
#  ['man', 'moment', 'geheim', 'werkt', 'handboek_populisme', 'http'],
#  ['patrick',
#   'schie_directeur',
#   'telderstichting_vvd',
#   'nten_diepste',
#   'onliberaal_vindt',
#   'schie',
#   'donorwet',
#   'eerst'],
#  ['alleen',
#   'ollongren',
#   'rutte',
#   'kennelijk_enig',
#   'benul',
#   'staatsrecht',
#   'minister',
#   'minister',
#   'ee'],
#  ['baudet', 'obsessie'],
#  ['leveamsterdam',
#   'openbaar_vervoer',
#   'ooit',
#   'dachten',
#   'noord_zuidlijn',
#   'kosten'],
#  ['duivels_arrogant',
#   'productieve_eenzame',
#   'ouderen_euthaniseren',
#   'organen_roven',
#   'privacy_stelen',
#   'sleepw'],
#  ['heel',
#   'mooi_nieuws',
#   'juf_ank',
#   'leraren',
#   'kabinet',
#   'begint',
#   'verlagen',
#   'werkdruk_strijdt',
#   'jaren'],
#  ['heel',
#   'mooi_nieuws',
#   'werkdrukakkoord_tussen',
#   'onderwijsveld',
#   'jaar',
#   'scholen',
#   'vruchten'],
#  ['mooi_resultaat', 'samenwerken_loont'],
#  ['gedreven', 'persoonlijke_rancune', 'mag', 'journalistiek_bedrijven'],
#  ['verwijt',
#   'baudet',
#   'keus',
#   'maakt',
#   'stellingen',
#   'bordje',
#   'daarvoor',
#   'groen',
#   'rood',
#   'telken'],
#  ['joost', 'trap', 'grote_minne', 'manipulatie', 'gang'],
#  ['alleen',
#   'ollongren',
#   'rutte',
#   'kennelijk_enig',
#   'benul',
#   'staatsrecht',
#   'minister',
#   'minister',
#   'ee'],
#  ['duivels_arrogant',
#   'productieve_eenzame',
#   'ouderen_euthaniseren',
#   'organen_roven',
#   'privacy_stelen',
#   'sleepw'],
#  ['gedreven', 'persoonlijke_rancune', 'mag', 'journalistiek_bedrijven'],
#  ['ergens', 'gemeen'],
#  ['mooi_resultaat', 'samenwerken_loont'],
#  ['man',
#   'lekker_edoch',
#   'eu',
#   'baas',
#   'vvd',
#   'weet',
#   'wel',
#   'eu_lovers',
#   'kabinet'],
#  ['factfreethierry', 'nooit', 'goed', 'cijfers', 'verzon', 'ooit'],
#  ['bijzonder', 'prettig', 'gezagsdragers', 'volk', 'herzien'],
#  ['bijzonder', 'prettig', 'gezagsdragers', 'volk', 'herzien', 'derh'],
#  ['man',
#   'lekker_edoch',
#   'eu',
#   'baas',
#   'vvd',
#   'weet',
#   'wel',
#   'eu_lovers',
#   'kabinet'],
#  ['daarnaast',
#   'werden',
#   'struiken',
#   'waar',
#   'onderw',
#   'vogels',
#   'jonge',
#   'bomen',
#   'stonden',
#   'grond',
#   'gelijkt'],
#  ['rutte', 'vvd', 'steunt', 'rutte', 'neemt', 'maat', 'racis'],
#  ['definitief', 'partijen', 'mee', 'volgorde', 'pvda', 'vvd', 'cda'],
#  ['heel',
#   'mooi_nieuws',
#   'juf_ank',
#   'leraren',
#   'kabinet',
#   'begint',
#   'verlagen',
#   'werkdruk_strijdt',
#   'jaren'],
#  ['gemeente', 'geeft', 'geheim', 'kiezer', 'afgerekend_ton'],
#  ['voortdurend', 'schiphol', 'goed', 'economie', 'goed', 'mensen', 'aldus'],
#  ['zorgelijk_vind',
#   'keer',
#   'keer',
#   'suggestie_wekt',
#   'mensen',
#   'partij',
#   'verd'],
#  ['gaat', 'gemeente', 'bobos'],
#  ['walgelijke',
#   'tweet',
#   'nde',
#   'domheid',
#   'leugens',
#   'iccp',
#   'wetenschap',
#   'presenteert',
#   'nbove'],
#  ['leefbaar', 'amsterdammers', 'auto', 'lijkt', 'toeristen', 'dagj'],
#  ['patrick',
#   'schie_directeur',
#   'telderstichting_vvd',
#   'nten_diepste',
#   'onliberaal_vindt',
#   'schie',
#   'donorwet',
#   'eerst'],
#  ['fase', 'aanvraag', 'referendum', 'wet_hillen', 'kbo_pcob'],
#  ['man',
#   'lekker_edoch',
#   'eu',
#   'baas',
#   'vvd',
#   'weet',
#   'wel',
#   'eu_lovers',
#   'kabinet'],
#  ['mooi_resultaat', 'samenwerken_loont'],
#  ['jongeren', 'lijsten', 'staan'],
#  ['bobos',
#   'debat',
#   'gaat',
#   'gemeente',
#   'bobos',
#   'opper',
#   'bobo',
#   'rutte',
#   'ontbreekt'],
#  ['gedreven', 'persoonlijke_rancune', 'mag', 'journalistiek_bedrijven'],
#  ['opvalt', 'msm', 'racisme', 'sporen', 'anti', 'racisten_openlijk', 'rac'],
#  ['februari',
#   'aanstaande',
#   'organiseert',
#   'zzp',
#   'cafe',
#   'tweede_kamerlid',
#   'luno',
#   'kitchen'],
#  ['openbaar_vervoer',
#   'snel',
#   'betaalbaar',
#   'sp_knokt',
#   'behoud',
#   'metrolijnen_terwijl',
#   'kabinet',
#   'btw',
#   'kaartje'],
#  ['patrick',
#   'schie_directeur',
#   'telderstichting_vvd',
#   'nten_diepste',
#   'onliberaal_vindt',
#   'schie',
#   'donorwet',
#   'eerst'],
#  ['nico', 'mening', 'gemeente', 'woorden', 'aandac'],
#  ['moeten',
#   'eerst',
#   'gemeente',
#   'fonds',
#   'aanvullen',
#   'troep',
#   'landelijk',
#   'maakt',
#   'gemeente',
#   'schuiven'],
#  ['suggesties', 'onderbouwde', 'feiten', 'links'],
#  ['opvalt', 'msm', 'racisme', 'sporen', 'anti', 'racisten_openlijk', 'rac'],
#  ['grote', 'woorden', 'meneer', 'asscher', 'nou', 'nachtmerries', 'partij'],
#  ['lijstnummer', 'gaan', 'staat', 'aantal_zetels', 'waar', 'gaat', 'ste'],
#  ['kabinetsreactie',
#   'initiatiefnota',
#   'nonverstandig_kabinet',
#   'gaat',
#   'mee',
#   'voorstellen',
#   'priva'],
#  ['heel',
#   'mooi_nieuws',
#   'juf_ank',
#   'leraren',
#   'kabinet',
#   'begint',
#   'verlagen',
#   'werkdruk_strijdt',
#   'jaren'],
#  ['alleen',
#   'ollongren',
#   'rutte',
#   'kennelijk_enig',
#   'benul',
#   'staatsrecht',
#   'minister',
#   'minister',
#   'ee'],
#  ['pechtold',
#   'nos_journaal',
#   'plaats',
#   'racisme',
#   'journalist',
#   'baudet',
#   'pechtold',
#   'zegt'],
#  ['stem', 'maart', 'groenlinks', 'stem', 'groenlinks', 'kies_jij', 'soc'],
#  ['roept', 'cda', 'orde', 'groenste_kabinet', 'ooit', 'geschapen', 'oneerl'],
#  ['man',
#   'lekker_edoch',
#   'eu',
#   'baas',
#   'vvd',
#   'weet',
#   'wel',
#   'eu_lovers',
#   'kabinet'],
#  ['natuurlijk',
#   'pvv',
#   'grootste',
#   'almere',
#   'wel',
#   'gekeken',
#   'enorme',
#   'oetlullen',
#   'sukke'],
#  ['natuurlijk',
#   'pvv',
#   'grootste',
#   'almere',
#   'wel',
#   'gekeken',
#   'enorme',
#   'oetlullen',
#   'sukke'],
#  ['natuurlijk',
#   'pvv',
#   'grootste',
#   'almere',
#   'wel',
#   'gekeken',
#   'enorme',
#   'oetlullen',
#   'sukke'],
#  ['natuurlijk',
#   'pvv',
#   'grootste',
#   'almere',
#   'wel',
#   'gekeken',
#   'enorme',
#   'oetlullen',
#   'sukke'],
#  ['natuurlijk',
#   'pvv',
#   'grootste',
#   'almere',
#   'wel',
#   'gekeken',
#   'enorme',
#   'oetlullen',
#   'sukke'],
#  ['bnr',
#   'gaat',
#   'lekker',
#   'spin',
#   'echte',
#   'zzp_ers',
#   'opdrachtgevers_ervaren',
#   'heel',
#   'anders',
#   'namelijk'],
#  ['man',
#   'lekker_edoch',
#   'eu',
#   'baas',
#   'vvd',
#   'weet',
#   'wel',
#   'eu_lovers',
#   'kabinet'],
#  ['kabinet',
#   'bezig',
#   'mogen',
#   'weten',
#   'misschien',
#   'moeten',
#   'wel',
#   'arm',
#   'wo'],
#  ['lelystadairport',
#   'word',
#   'gewoon',
#   'weer',
#   'belazerd',
#   'enz',
#   'weet',
#   'stemt',
#   'gr'],
#  ['zit',
#   'woonlasten',
#   'energie',
#   'belastingen',
#   'aandacht',
#   'energielasten',
#   'verl'],
#  ['weer', 'komt', 'leider', 'concreet_voorstel', 'kabinet_schaf', 'af'],
#  ['alleen',
#   'ollongren',
#   'rutte',
#   'kennelijk_enig',
#   'benul',
#   'staatsrecht',
#   'minister',
#   'minister',
#   'ee'],
#  ['pechtold',
#   'wijst',
#   'debat',
#   'racisme',
#   'afgelopen',
#   'week',
#   'kamer',
#   'af',
#   'valt',
#   'wel',
#   'racisme',
#   'baudet',
#   'debat'],
#  ['los',
#   'morgen',
#   'rotterdam_ontwaken',
#   'leefbaar_rotterdam',
#   'nachtvanlr',
#   'gr'],
#  ['alleen',
#   'ollongren',
#   'rutte',
#   'kennelijk_enig',
#   'benul',
#   'staatsrecht',
#   'minister',
#   'minister',
#   'ee'],
#  ['wethouder',
#   'groene',
#   'stichtse_vecht',
#   'wethouder',
#   'pieter',
#   'groene',
#   'gem'],
#  ['waar_haal',
#   'gore_lef',
#   'volk',
#   'referendum',
#   'afnemen',
#   'grote_mond',
#   'opzetten',
#   'kern'],
#  ['rutte', 'vvd', 'steunt', 'rutte', 'neemt', 'maat', 'racis'],
#  ['lelystadairport',
#   'word',
#   'gewoon',
#   'weer',
#   'belazerd',
#   'enz',
#   'weet',
#   'stemt',
#   'gr'],
#  ['suggesties', 'onderbouwde', 'feiten', 'links', 'ni'],
#  ['amsterdam',
#   'liever',
#   'transformeren',
#   'verzameling',
#   'zeer',
#   'elitaire',
#   'wijk'],
#  ['lokaal',
#   'sociaal',
#   'gaat',
#   'start',
#   'campagne',
#   'lokaal',
#   'sociaal',
#   'februari',
#   'pvda',
#   'mook',
#   'middelaar',
#   'zie'],
#  ['even', 'alleen', 'erger', 'lelystadairport', 'groenlinks'],
#  ['laat', 'aandacht', 'pers', 'landelijke', 'verkiezingen', 'gemee'],
#  ['vorige',
#   'kabinet',
#   'volgens',
#   'ging',
#   'amsterdam',
#   'vanavond',
#   'amsterdamkiest',
#   'leveamsterdam'],
#  ['gewone_thuiszorger',
#   'amsterdam',
#   'vertrekken',
#   'beleid_kabinet',
#   'sociale'],
#  ['gewone_thuiszorger',
#   'amsterdam',
#   'vertrekken',
#   'beleid_kabinet',
#   'sociale_huurwoningen',
#   'word'],
#  ['wethouder',
#   'groene',
#   'stichtse_vecht',
#   'wethouder',
#   'pieter',
#   'groene',
#   'gem'],
#  ['lelystadairport',
#   'word',
#   'gewoon',
#   'weer',
#   'belazerd',
#   'enz',
#   'weet',
#   'stemt',
#   'gr'],
#  ['weer',
#   'komt',
#   'leider',
#   'concreet_voorstel',
#   'kabinet_schaf',
#   'af_leveamsterda'],
#  ['vvd', 'pvda', 'groenl'],
#  ['nederlands_bekendste',
#   'droogkloot_marcel',
#   'roosmalen_sloopt',
#   'helemaal',
#   'moeder_luister',
#   'topper'],
#  ['gewone_thuiszorger',
#   'amsterdam',
#   'vertrekken',
#   'beleid_kabinet',
#   'sociale_huurwoningen',
#   'word'],
#  ['gedreven', 'persoonlijke_rancune', 'mag', 'journalistiek_bedrijven'],
#  ['joost', 'trap', 'grote_minne', 'manipulatie', 'gang'],
#  ['heel',
#   'mooi_nieuws',
#   'werkdrukakkoord_tussen',
#   'onderwijsveld',
#   'jaar',
#   'scholen',
#   'vruchten'],
#  ['openbaar_vervoer',
#   'snel',
#   'betaalbaar',
#   'sp_knokt',
#   'behoud',
#   'metrolijnen_terwijl',
#   'kabinet',
#   'btw',
#   'kaartje'],
#  ['gemeente', 'geeft', 'geheim', 'kiezer', 'afgerekend_ton'],
#  ['groen_links',
#   'baudet',
#   'maak',
#   'nieuwe',
#   'verkiezingen',
#   'let',
#   'zeart',
#   'ma'],
#  ['aldus', 'leugenaar', 'durft', 'partij', 'democratie'],
#  ['heel',
#   'mooi_nieuws',
#   'werkdrukakkoord_tussen',
#   'onderwijsveld',
#   'jaar',
#   'scholen',
#   'vruchten'],
#  ['minister',
#   'onze_samenleving',
#   'schreeuwt',
#   'jongeren',
#   'praktisch',
#   'gevormd',
#   'plekje'],
#  ['gedreven', 'persoonlijke_rancune', 'mag', 'journalistiek_bedrijven'],
#  ['regering', 'neemt', 'clowneske', 'vormen', 'nalsof', 'handpop', 'hoor'],
#  ['opnieuw',
#   'uiterst_merkwaardig',
#   'dubbelspel',
#   'groenlinkser_liesbeth',
#   'tongeren',
#   'waarom',
#   'maakte',
#   'groningse'],
#  ['heel',
#   'mooi_nieuws',
#   'juf_ank',
#   'leraren',
#   'kabinet',
#   'begint',
#   'verlagen',
#   'werkdruk_strijdt',
#   'jaren'],
#  ['gewone_thuiszorger',
#   'amsterdam',
#   'vertrekken',
#   'beleid_kabinet',
#   'sociale_huurwoningen',
#   'word'],
#  ['tenzij',
#   'schoonopgewekte',
#   'energie',
#   'vervuil',
#   'alleen',
#   'productie',
#   'dzeopwekker',
#   'daa'],
#  ['zaal',
#   'lacht',
#   'weet',
#   'zeker',
#   'juist',
#   'zz',
#   'belachelijk',
#   'maken',
#   'baudet',
#   'volstaan'],
#  ['leuk',
#   'onnozel',
#   'commentaar',
#   'alsof',
#   'wel',
#   'oplossing',
#   'uitdijende',
#   'vliegverkeer',
#   'denk'],
#  ['gedreven', 'persoonlijke_rancune', 'mag', 'journalistiek_bedrijven'],
#  ['alleen',
#   'ollongren',
#   'rutte',
#   'kennelijk_enig',
#   'benul',
#   'staatsrecht',
#   'minister',
#   'minister',
#   'ee'],
#  ['hermetisch_gesloten', 'doorgeschoten', 'hoger', 'onderwijs', 'helemaa'],
#  ['racisme', 'zegt', 'gaat', 'nieuwe', 'nederlanders', 'antisemi'],
#  ['partijen', 'volgorde', 'christenunie', 'gemeente', 'belangen', 'cda'],
#  ['ah_vertrekt', 'zei', 'racistische', 'club', 'zei_studentikoos'],
#  ['laatste',
#   'deel',
#   'werkbezoek',
#   'snew',
#   'snew',
#   'volop',
#   'bezig',
#   'circulaire_economie',
#   'inspirerend'],
#  ['beste',
#   'nclimate',
#   'change',
#   'wel',
#   'mens',
#   'fake',
#   'discussie',
#   'sowieso'],
#  ['compleet_kafka',
#   'nrutte',
#   'vvd',
#   'ollongren',
#   'vinden',
#   'baudet',
#   'fvd',
#   'geobsedeerd',
#   'praten',
#   'rassen'],
#  ['hermetisch_gesloten', 'doorgeschoten', 'hoger', 'onderwijs', 'helemaa'],
#  ['wilders',
#   'discrimineerde',
#   'geloof',
#   'voegt',
#   'toe',
#   'ras_geslacht',
#   'geaardheid',
#   'leveamsterdam'],
#  ['gaan', 'soros', 'aanpakken', 'schreeuwen', 'inmenging', 'russen', 'sl'],
#  ['opnieuw',
#   'uiterst_merkwaardig',
#   'dubbelspel',
#   'groenlinkser_liesbeth',
#   'tongeren',
#   'waarom',
#   'maakte',
#   'groningse'],
#  ['onzin', 'anton', 'gaat', 'stroom', 'nepnieuws', 'ken', 'jaren'],
#  ['gewone_thuiszorger',
#   'amsterdam',
#   'vertrekken',
#   'beleid_kabinet',
#   'sociale_huurwoningen',
#   'word'],
#  ['hohohoho',
#   'nde',
#   'gemeenteraad',
#   'vorig_jaar',
#   'besloten',
#   'voorrang_geven',
#   'allochtone',
#   'jongeren'],
#  ['wilders',
#   'discrimineerde',
#   'geloof',
#   'voegt',
#   'toe',
#   'ras_geslacht',
#   'geaardheid',
#   'le'],
#  ['aantal_daklozen',
#   'verdubbeld',
#   'eenvandaag',
#   'krijg',
#   'regering',
#   'geleid',
#   'kost'],
#  ['amsterdam', 'racisme', 'zetel', 'raad', 'zegt', 'leveamsterdam'],
#  ['groenlinks',
#   'eist_duidelijkheid',
#   'extra',
#   'vliegbewegingen',
#   'lelystad_airport',
#   'kamerlid',
#   'suzanne_kroger',
#   'exact',
#   'weten'],
#  ['ho_ho',
#   'gemeenteraad',
#   'vorig_jaar',
#   'besloten',
#   'voorrang_geven',
#   'allochtone',
#   'jongeren'],
#  ['sinds_wanneer',
#   'bepaalt',
#   'democratisch',
#   'politieke',
#   'partij',
#   'plaats',
#   'nederland',
#   'nwaanzin'],
#  ['demoniseer',
#   'extra_klapvee',
#   'helpen_tevergeefs',
#   'baudet',
#   'maakt',
#   'duidelijk',
#   'ruimte'],
#  ['zorgelijk_vind',
#   'keer',
#   'keer',
#   'suggestie_wekt',
#   'mensen',
#   'partij',
#   'verd'],
#  ['dictatoriaal',
#   'gedrag',
#   'net',
#   'democratie',
#   'hoog',
#   'mondje',
#   'baudet',
#   'neemt'],
#  ['gewone_thuiszorger',
#   'amsterdam',
#   'vertrekken',
#   'beleid_kabinet',
#   'sociale_huurwoningen',
#   'word'],
#  ['weer',
#   'komt',
#   'leider',
#   'concreet_voorstel',
#   'kabinet_schaf',
#   'af_leveamsterda'],
#  ['demoniseer',
#   'extra_klapvee',
#   'helpen_tevergeefs',
#   'baudet',
#   'maakt',
#   'duidelijk',
#   'ruimte',
#   'rac'],
#  ['demoniseer',
#   'extra_klapvee',
#   'helpen_tevergeefs',
#   'baudet',
#   'maakt',
#   'duidelijk',
#   'ruimte',
#   'rac'],
#  ['demoniseer',
#   'extra_klapvee',
#   'helpen_tevergeefs',
#   'baudet',
#   'maakt',
#   'duidelijk',
#   'ruimte',
#   'rac'],
#  ['gewone_thuiszorger',
#   'amsterdam',
#   'vertrekken',
#   'beleid_kabinet',
#   'sociale_huurwoningen',
#   'word'],
#  ['demoniseer',
#   'extra_klapvee',
#   'helpen_tevergeefs',
#   'baudet',
#   'maakt',
#   'duidelijk',
#   'ruimte',
#   'rac'],
#  ['demoniseer',
#   'extra_klapvee',
#   'helpen_tevergeefs',
#   'baudet',
#   'maakt',
#   'duidelijk',
#   'ruimte',
#   'rac'],
#  ['gewone_thuiszorger',
#   'amsterdam',
#   'vertrekken',
#   'beleid_kabinet',
#   'sociale_huurwoningen',
#   'word'],
#  ['demoniseer',
#   'extra_klapvee',
#   'helpen_tevergeefs',
#   'baudet',
#   'maakt',
#   'duidelijk',
#   'ruimte',
#   'rac'],
#  ['demoniseer',
#   'extra_klapvee',
#   'helpen_tevergeefs',
#   'baudet',
#   'maakt',
#   'duidelijk',
#   'ruimte',
#   'rac'],
#  ['demoniseer',
#   'extra_klapvee',
#   'helpen_tevergeefs',
#   'baudet',
#   'maakt',
#   'duidelijk',
#   'ruimte',
#   'rac'],
#  ['weer', 'bezuiniging', 'bijna_procent', 'groepen', 'kabinet', 'vvd', 'cda'],
#  ['alleen',
#   'ollongren',
#   'rutte',
#   'kennelijk_enig',
#   'benul',
#   'staatsrecht',
#   'minister',
#   'minister',
#   'ee'],
#  ['discrimineren',
#   'geloof',
#   'pvv',
#   'gaat',
#   'baudet',
#   'verder',
#   'geslacht',
#   'ras',
#   'aldus',
#   'pechtold',
#   'weer',
#   'weerlegging'],
#  ['jochie', 'links', 'groen', 'lezen', 'leren'],
#  ['demoniseer',
#   'extra_klapvee',
#   'helpen_tevergeefs',
#   'baudet',
#   'maakt',
#   'duidelijk',
#   'ruimte',
#   'rac'],
#  ['amsterdam', 'racisme', 'zetel', 'raad', 'zegt', 'leveamsterdam'],
#  ['noem',
#   'expres',
#   'vreemde',
#   'linkse',
#   'standpunten',
#   'vind',
#   'onderwijs',
#   'toega'],
#  ['patrick',
#   'schie_directeur',
#   'telderstichting_vvd',
#   'nten_diepste',
#   'onliberaal_vindt',
#   'schie',
#   'donorwet',
#   'eerst'],
#  ['wetenschap',
#   'klimaat',
#   'vertrouwt',
#   'klaver',
#   'wel',
#   'ras',
#   'hypocriet',
#   'groenlinks',
#   'jesseklaver'],
#  ['demoniseer',
#   'extra_klapvee',
#   'helpen_tevergeefs',
#   'baudet',
#   'maakt',
#   'duidelijk',
#   'ruimte',
#   'rac'],
#  ['joost', 'trap', 'grote_minne', 'manipulatie', 'gang'],
#  ['zonnepanelen_plan',
#   'gratis_stroom',
#   'gemeente',
#   'amsterdam',
#   'kost_honderden'],
#  ['gewone_thuiszorger',
#   'amsterdam',
#   'vertrekken',
#   'beleid_kabinet',
#   'sociale_huurwoningen',
#   'word'],
#  ['patrick',
#   'schie_directeur',
#   'telderstichting_vvd',
#   'nten_diepste',
#   'onliberaal_vindt',
#   'schie',
#   'donorwet',
#   'eerst'],
#  ['alleen',
#   'ollongren',
#   'rutte',
#   'kennelijk_enig',
#   'benul',
#   'staatsrecht',
#   'minister',
#   'minister',
#   'ee'],
#  ['vvd',
#   'kwam',
#   'jaren',
#   'groene',
#   'hart',
#   'waardevolle',
#   'buitengebieden',
#   'lang',
#   'voord'],
#  ['gewone_thuiszorger',
#   'amsterdam',
#   'vertrekken',
#   'beleid_kabinet',
#   'sociale_huurwoningen',
#   'word'],
#  ['demoniseer',
#   'extra_klapvee',
#   'helpen_tevergeefs',
#   'baudet',
#   'maakt',
#   'duidelijk',
#   'ruimte',
#   'rac'],
#  ['interview', 'bron', 'ophef', 'hebt', 'verkeerd_begrepen'],
#  ['livestream', 'ascher', 'liegt', 'mening', 'verstand'],
#  ['wilders',
#   'discrimineerde',
#   'geloof',
#   'voegt',
#   'toe',
#   'ras_geslacht',
#   'geaardheid',
#   'le'],
#  ['relletje',
#   'kwaad',
#   'haalt',
#   'yernaz',
#   'podium',
#   'leugens',
#   'verkondigd',
#   'smaad',
#   'laster'],
#  ['wilders',
#   'discrimineert',
#   'basis',
#   'religie',
#   'voegt',
#   'discriminatie',
#   'bas'],
#  ['wetenschap',
#   'klimaat',
#   'vertrouwt',
#   'klaver',
#   'wel',
#   'ras',
#   'hypocriet',
#   'jesseklaver',
#   'groenlinks'],
#  ['gewone_thuiszorger',
#   'amsterdam',
#   'vertrekken',
#   'beleid_kabinet',
#   'sociale_huurwoningen',
#   'word'],
#  ['gedreven', 'persoonlijke_rancune', 'mag', 'journalistiek_bedrijven'],
#  ['discimineren',
#   'grond',
#   'geslacht',
#   'ras',
#   'geaardheid',
#   'doet',
#   'aldus',
#   'demoniseren',
#   'stoppen'],
#  ['gaf',
#   'baudet',
#   'kans',
#   'uitspraken',
#   'racisme',
#   'terug',
#   'nemen',
#   'baudet',
#   'doet',
#   'leveamsterdam_debalie'],
#  ['demoniseer',
#   'extra_klapvee',
#   'helpen_tevergeefs',
#   'baudet',
#   'maakt',
#   'duidelijk',
#   'ruimte',
#   'rac'],
#  ['wilders',
#   'discrimineerde',
#   'geloof',
#   'voegt',
#   'toe',
#   'ras_geslacht',
#   'geaardheid',
#   'le'],
#  ['demoniseer',
#   'extra_klapvee',
#   'helpen_tevergeefs',
#   'baudet',
#   'maakt',
#   'duidelijk',
#   'ruimte',
#   'rac'],
#  ['gewone_thuiszorger',
#   'amsterdam',
#   'vertrekken',
#   'beleid_kabinet',
#   'sociale_huurwoningen',
#   'word'],
#  ['demoniseer',
#   'extra_klapvee',
#   'helpen_tevergeefs',
#   'baudet',
#   'maakt',
#   'duidelijk',
#   'ruimte',
#   'rac'],
#  ['discriminatie', 'racisme', 'respect', 'eerbied', 'baudetracist'],
#  ['grondstoffen', 'gebruiken', 'goed', 'afhankelijk', 'corrupte', 'lande'],
#  ['zorgelijk_vind',
#   'keer',
#   'keer',
#   'suggestie_wekt',
#   'mensen',
#   'partij',
#   'verd'],
#  ['discrimineren',
#   'geloof',
#   'pvv',
#   'gaat',
#   'baudet',
#   'verder',
#   'geslacht',
#   'ras',
#   'aldus',
#   'pechtold',
#   'weer',
#   'weerlegging'],
#  ['racisme', 'noh_wacht'],
#  ['buma',
#   'vindt',
#   'respect',
#   'moeten',
#   'meningen',
#   'baudet',
#   'ter_discussie',
#   'staat',
#   'fuck',
#   'buma',
#   'voo'],
#  ['gewone_thuiszorger',
#   'amsterdam',
#   'vertrekken',
#   'beleid_kabinet',
#   'sociale_huurwoningen',
#   'word'],
#  ['openbaar_vervoer',
#   'snel',
#   'betaalbaar',
#   'sp_knokt',
#   'behoud',
#   'metrolijnen_terwijl',
#   'kabinet',
#   'btw',
#   'kaartje'],
#  ['discrimineren',
#   'geloof',
#   'pvv',
#   'gaat',
#   'baudet',
#   'verder',
#   'geslacht',
#   'ras',
#   'aldus',
#   'pechtold',
#   'weer',
#   'weerlegging'],
#  ['demoniseer',
#   'extra_klapvee',
#   'helpen_tevergeefs',
#   'baudet',
#   'maakt',
#   'duidelijk',
#   'ruimte',
#   'rac'],
#  ['demoniseer',
#   'extra_klapvee',
#   'helpen_tevergeefs',
#   'baudet',
#   'maakt',
#   'duidelijk',
#   'ruimte',
#   'rac'],
#  ['meeliften', 'succes', 'tv', 'serie'],
#  ['hele', 'interview', 'waar', 'ophef', 'gaat', 'rassen', 'praat'],
#  ['roept', 'cda', 'orde', 'groenste_kabinet', 'ooit', 'geschapen', 'oneerl'],
#  ['wilders',
#   'discrimineerde',
#   'geloof',
#   'voegt',
#   'toe',
#   'ras_geslacht',
#   'geaardheid',
#   'le'],
#  ['buma',
#   'vindt',
#   'respect',
#   'moeten',
#   'meningen',
#   'baudet',
#   'ter_discussie',
#   'staat',
#   'fuck',
#   'buma'],
#  ['zonnepanelen_plan',
#   'gratis_stroom',
#   'gemeente',
#   'amsterdam',
#   'kost_honderden'],
#  ['verlichting', 'erasmusbrug', 'aangepast', 'nacht', 'leefbaar_rotterdam'],
#  ['demoniseer',
#   'extra_klapvee',
#   'helpen_tevergeefs',
#   'baudet',
#   'maakt',
#   'duidelijk',
#   'ruimte',
#   'rac'],
#  ['buma',
#   'vindt',
#   'respect',
#   'moeten',
#   'meningen',
#   'baudet',
#   'ter_discussie',
#   'staat',
#   'fuck',
#   'buma',
#   'raci'],
#  ['baudet', 'obsessie'],
#  ['demoniseer',
#   'extra_klapvee',
#   'helpen_tevergeefs',
#   'baudet',
#   'maakt',
#   'duidelijk',
#   'ruimte',
#   'rac'],
#  ['zaak',
#   'amsterdams',
#   'vastgoed',
#   'vvd',
#   'den_haag',
#   'danig',
#   'problemen',
#   'brengt',
#   'mogelijk',
#   'kabinet',
#   'nhttp'],
#  ['gemeente', 'geeft', 'geheim', 'kiezer', 'afgerekend_ton'],
#  ['racisme', 'ruimte', 'democratie', 'binnen', 'sad'],
#  ['partij', 'college', 'zat', 'communistische_cpn', 'leveamsterdam'],
#  ['vluchten',
#   'nodig',
#   'wel',
#   'aandacht',
#   'mens',
#   'milieu',
#   'uitbreiding',
#   'lelystad_airport',
#   'gaat'],
#  ['gewone_thuiszorger',
#   'amsterdam',
#   'vertrekken',
#   'beleid_kabinet',
#   'sociale_huurwoningen',
#   'word'],
#  ['pechtold',
#   'weet',
#   'waarvoor',
#   'staat',
#   'grappig',
#   'blijkbaar',
#   'nederlanders',
#   'wel',
#   'begrijpen',
#   'gezi'],
#  ['opnieuw',
#   'gerommel',
#   'vliegveld_lelystad',
#   'vliegbewegingen',
#   'opeens',
#   'winst',
#   'gaat',
#   'schiphol'],
#  ['intelligentie', 'verander', 'nou', 'onderw'],
#  ['ras', 'rassentheorie', 'helemaal', 'beleid', 'enige', 'fvd', 'gezegd'],
#  ['verlate',
#   'foto',
#   'campagneoverleg',
#   'chips',
#   'nootjes',
#   'gezelligheid',
#   'energie',
#   'cusgp',
#   'hartvoorelkaar'],
#  ['heel',
#   'mooi_nieuws',
#   'juf_ank',
#   'leraren',
#   'kabinet',
#   'begint',
#   'verlagen',
#   'werkdruk_strijdt',
#   'jaren'],
#  ['pechtold',
#   'uitnodiging',
#   'asscher',
#   'werkt',
#   'samen',
#   'link',
#   'leveamsterdam'],
#  ['gastarbeiders', 'recht'],
#  ['partij', 'college', 'zat', 'communistische_cpn', 'leveamsterdam'],
#  ['alleen',
#   'ollongren',
#   'rutte',
#   'kennelijk_enig',
#   'benul',
#   'staatsrecht',
#   'minister',
#   'minister',
#   'ee'],
#  ['wahahaha_pechtold',
#   'leefbaar_rotterdam',
#   'vier_jaar',
#   'geleden',
#   'gewone',
#   'partij',
#   'discrimineerde_hahaha',
#   'leveamsterdam'],
#  ['gewone_thuiszorger',
#   'amsterdam',
#   'vertrekken',
#   'beleid_kabinet',
#   'sociale_huurwoningen',
#   'word'],
#  ['bizarre', 'vragen', 'joh', 'beschuldigen', 'obse'],
#  ['gaat', 'verkeer', 'gemeente', 'word', 'schiet', 'ziek'],
#  ['alleen',
#   'ollongren',
#   'rutte',
#   'kennelijk_enig',
#   'benul',
#   'staatsrecht',
#   'minister',
#   'minister',
#   'ee'],
#  ['buma',
#   'vindt',
#   'respect',
#   'moeten',
#   'meningen',
#   'baudet',
#   'ter_discussie',
#   'staat',
#   'fuck',
#   'buma',
#   'raci'],
#  ['constante_attack', 'uitspraak', 'context_gehaald', 'groep', 'rassenobses'],
#  ['mannetje', 'penthouse', 'gevaarlijker', 'linksche', 're'],
#  ['gewone_thuiszorger',
#   'amsterdam',
#   'vertrekken',
#   'beleid_kabinet',
#   'sociale_huurwoningen',
#   'word'],
#  ['maak', 'duidelijk'],
#  ['mengele', 'jaloers', 'donorwet'],
#  ['rotterdam', 'uitsluiten_vanwege', 'racisme', 'steeds_maffer', 'echt'],
#  ['gewone_thuiszorger',
#   'amsterdam',
#   'vertrekken',
#   'beleid_kabinet',
#   'sociale_huurwoningen',
#   'word'],
#  ['demoniseer',
#   'extra_klapvee',
#   'helpen_tevergeefs',
#   'baudet',
#   'maakt',
#   'duidelijk',
#   'ruimte',
#   'rac'],
#  ['pechtold',
#   'baudet',
#   'wel',
#   'durft',
#   'vallen',
#   'zaaltje',
#   'amsterdam',
#   'national'],
#  ['duidelijk', 'beste_debater', 'waar', 'blijven', 'mannen', 'grote_mond'],
#  ['wahahaha_pechtold',
#   'leefbaar_rotterdam',
#   'vier_jaar',
#   'geleden',
#   'gewone',
#   'partij',
#   'discrimineerde_hahaha',
#   'leveams'],
#  ['debat',
#   'debalie',
#   'hoop',
#   'vaker',
#   'zien_bedeesd',
#   'schaamrood',
#   'kaken_stamelend',
#   'meneer'],
#  ['rotterdam', 'uitsluiten_vanwege', 'racisme', 'steeds_maffer', 'echt'],
#  ['discriminatie', 'racisme', 'respect', 'eerbied', 'baudetracist'],
#  ['wahahaha_pechtold',
#   'leefbaar_rotterdam',
#   'vier_jaar',
#   'geleden',
#   'gewone',
#   'partij',
#   'discrimineerde_hahaha',
#   'leveams'],
#  ['openbaar_vervoer',
#   'belangrijk',
#   'stad',
#   'bereikbaar',
#   'houden',
#   'hekelt',
#   'terecht',
#   'btw_verhoging',
#   'ka'],
#  ['rotterdam', 'uitsluiten_vanwege', 'racisme', 'steeds_maffer', 'echt'],
#  ['rotterdam', 'uitsluiten_vanwege', 'racisme', 'steeds_maffer', 'echt'],
#  ['openbaar_vervoer',
#   'snel',
#   'betaalbaar',
#   'sp_knokt',
#   'behoud',
#   'metrolijnen_terwijl',
#   'kabinet',
#   'btw',
#   'kaartje'],
#  ['kabinet',
#   'verhoogt',
#   'btw',
#   'kaartjes',
#   'openbaar_vervoer',
#   'laten',
#   'zorgen',
#   'amste'],
#  ['zaal',
#   'lacht',
#   'weet',
#   'zeker',
#   'juist',
#   'zz',
#   'belachelijk',
#   'maken',
#   'baudet',
#   'volstaan'],
#  ['pechtold',
#   'uitnodiging',
#   'asscher',
#   'werkt',
#   'samen',
#   'link',
#   'leveamsterdam'],
#  ['kritiek',
#   'israel',
#   'pas',
#   'racisme_genocidaal',
#   'racisme_cidi',
#   'christenunie',
#   'cda',
#   'pvda',
#   'groenlinks',
#   'dwars'],
#  ['leider',
#   'kabinet',
#   'amsterdam',
#   'helpen',
#   'btw',
#   'verhogen',
#   'kaartjes',
#   'openbaar_vervoer'],
#  ['leefbaar_rotterdam', 'uitgesloten', 'coalitie', 'vorming'],
#  ['rotterdam', 'uitsluiten_vanwege', 'racisme', 'steeds_maffer', 'echt'],
#  ['man',
#   'amsterdam',
#   'bekrachtigd',
#   'grote',
#   'onzin',
#   'lelystad_airport',
#   'gaat',
#   'vlucht',
#   'anderhalf_uur',
#   'leugen',
#   'leve'],
#  ['eerst_herindelen',
#   'luchtruim',
#   'hogere_vliegroutes',
#   'ontzien',
#   'woonkernen',
#   'daarna',
#   'ka'],
#  ['demoniseer',
#   'extra_klapvee',
#   'helpen_tevergeefs',
#   'baudet',
#   'maakt',
#   'duidelijk',
#   'ruimte',
#   'rac'],
#  ['rotterdam', 'uitsluiten_vanwege', 'racisme', 'steeds_maffer', 'echt'],
#  ['rotterdam', 'uitsluiten_vanwege', 'racisme', 'steeds_maffer', 'echt'],
#  ['alleen',
#   'ollongren',
#   'rutte',
#   'kennelijk_enig',
#   'benul',
#   'staatsrecht',
#   'minister',
#   'minister',
#   'ee'],
#  ['demoniseer',
#   'extra_klapvee',
#   'helpen_tevergeefs',
#   'baudet',
#   'maakt',
#   'duidelijk',
#   'ruimte',
#   'rac'],
#  ['baudet',
#   'roept',
#   'nummer',
#   'amsterdam',
#   'podium',
#   'uitleg_geven',
#   'ophef',
#   'racisme'],
#  ['baudet',
#   'laat',
#   'hoek',
#   'drukken',
#   'waar',
#   'heerlijk',
#   'vindt',
#   'scoren',
#   'kernpunten'],
#  ['echt', 'weg_kwijt', 'partij', 'demonisering', 'uitsluiten'],
#  ['partijkartel', 'helemaal', 'open_discussie', 'partijkartel', 'lynchpartij'],
#  ['mening', 'wel_degelijk'],
#  ['rotterdam', 'uitsluiten_vanwege', 'racisme', 'steeds_maffer', 'echt'],
#  ['israelische',
#   'joden',
#   'zee',
#   'willen',
#   'indrijven',
#   'echt',
#   'racisme_cidi',
#   'christenunie',
#   'cda',
#   'pvda',
#   'groenlinks',
#   'dwars'],
#  ['gewone_thuiszorger',
#   'amsterdam',
#   'vertrekken',
#   'beleid_kabinet',
#   'sociale_huurwoningen',
#   'word'],
#  ['veelzeggend',
#   'partijverlaters',
#   'breekpunt',
#   'racisme',
#   'zeggenschap',
#   'kreg'],
#  ['demoniseer',
#   'extra_klapvee',
#   'helpen_tevergeefs',
#   'baudet',
#   'maakt',
#   'duidelijk',
#   'ruimte',
#   'rac'],
#  ['huiliehuilie',
#   'baudet',
#   'roept',
#   'ramataursing',
#   'podium',
#   'hulp',
#   'lastig',
#   'afstand_nemen'],
#  ['demoniseer',
#   'extra_klapvee',
#   'helpen_tevergeefs',
#   'baudet',
#   'maakt',
#   'duidelijk',
#   'ruimte',
#   'rac'],
#  ['rotterdam', 'uitsluiten_vanwege', 'racisme', 'steeds_maffer', 'echt'],
#  ['demoniseer',
#   'extra_klapvee',
#   'helpen_tevergeefs',
#   'baudet',
#   'maakt',
#   'duidelijk',
#   'ruimte',
#   'rac'],
#  ['heel',
#   'mooi_nieuws',
#   'juf_ank',
#   'leraren',
#   'kabinet',
#   'begint',
#   'verlagen',
#   'werkdruk_strijdt',
#   'jaren'],
#  ['rotterdam', 'uitsluiten_vanwege', 'racisme', 'steeds_maffer', 'echt'],
#  ['gemeente', 'geeft', 'geheim', 'kiezer', 'afgerekend_ton'],
#  ['zaal',
#   'lacht',
#   'weet',
#   'zeker',
#   'juist',
#   'zz',
#   'belachelijk',
#   'maken',
#   'baudet',
#   'volstaan'],
#  ['heel',
#   'mooi_nieuws',
#   'juf_ank',
#   'leraren',
#   'kabinet',
#   'begint',
#   'verlagen',
#   'werkdruk_strijdt',
#   'jaren'],
#  ['gewone_thuiszorger',
#   'amsterdam',
#   'vertrekken',
#   'beleid_kabinet',
#   'sociale_huurwoningen',
#   'word'],
#  ['partijkartel', 'helemaal', 'open_discussie', 'partijkartel', 'lynchpartij'],
#  ['baudet',
#   'laat',
#   'opnaaien',
#   'rest',
#   'speelt',
#   'smerig',
#   'onschuldige',
#   'man',
#   'weten'],
#  ['alleen',
#   'ollongren',
#   'rutte',
#   'kennelijk_enig',
#   'benul',
#   'staatsrecht',
#   'minister',
#   'minister',
#   'ee'],
#  ['heel',
#   'mooi_nieuws',
#   'juf_ank',
#   'leraren',
#   'kabinet',
#   'begint',
#   'verlagen',
#   'werkdruk_strijdt',
#   'jaren'],
#  ['gelukkig_mogelijkheden', 'gekregen_lees', 'structureel', 'technisch_vmbo'],
#  ['demoniseer',
#   'extra_klapvee',
#   'helpen_tevergeefs',
#   'baudet',
#   'maakt',
#   'duidelijk',
#   'ruimte',
#   'rac'],
#  ['baudet', 'zeggen', 'woorden', 'tuinkabouter', 'vader', 'tegenkom', 'ga'],
#  ['demoniseer',
#   'extra_klapvee',
#   'helpen_tevergeefs',
#   'baudet',
#   'maakt',
#   'duidelijk',
#   'ruimte',
#   'rac'],
#  ['gedreven', 'persoonlijke_rancune', 'mag', 'journalistiek_bedrijven'],
#  ['massai', 'langer', 'chinezen', 'gemiddeld', 'exact', 'even', 'hoog_iq'],
#  ['rotterdam', 'uitsluiten_vanwege', 'racisme', 'steeds_maffer', 'echt'],
#  ['heel',
#   'mooi_nieuws',
#   'juf_ank',
#   'leraren',
#   'kabinet',
#   'begint',
#   'verlagen',
#   'werkdruk_strijdt',
#   'jaren'],
#  ['verlichting', 'erasmusbrug', 'aangepast', 'nacht', 'leefbaar_rotterdam'],
#  ['rotterdam', 'uitsluiten_vanwege', 'racisme', 'steeds_maffer', 'echt'],
#  ['artikel', 'bestond', 'daarbij', 'vraag', 'af'],
#  ['terecht_punt',
#   'standpunten',
#   'echt',
#   'grote',
#   'themas',
#   'waar',
#   'gemeente',
#   'gaat',
#   'komen',
#   'nauwelij'],
#  ['demoniseer',
#   'extra_klapvee',
#   'helpen_tevergeefs',
#   'baudet',
#   'maakt',
#   'duidelijk',
#   'ruimte',
#   'rac'],
#  ['rotterdam', 'uitsluiten_vanwege', 'racisme', 'steeds_maffer', 'echt'],
#  ['hou', 'mond', 'democratie', 'durft', 'referendum', 'corrupte', 'zak_hooi'],
#  ['buma',
#   'vindt',
#   'respect',
#   'moeten',
#   'meningen',
#   'baudet',
#   'ter_discussie',
#   'staat',
#   'fuck',
#   'buma',
#   'raci'],
#  ['beweert',
#   'linkerkant',
#   'cda',
#   'sp',
#   'groen_links',
#   'raad',
#   'vakbond',
#   'samengewerkt',
#   'ston'],
#  ['demoniseer',
#   'extra_klapvee',
#   'helpen_tevergeefs',
#   'baudet',
#   'maakt',
#   'duidelijk',
#   'ruimte',
#   'rac'],
#  ['alleen',
#   'ollongren',
#   'rutte',
#   'kennelijk_enig',
#   'benul',
#   'staatsrecht',
#   'minister',
#   'minister',
#   'ee'],
#  ['opnieuw',
#   'uiterst_merkwaardig',
#   'dubbelspel',
#   'groenlinkser_liesbeth',
#   'tongeren',
#   'waarom',
#   'maakte',
#   'groningse'],
#  ['gaat', 'eigenlijk', 'referendum', 'steven', 'meneertje', 'pechtho'],
#  ['pechtold',
#   'uitnodiging',
#   'asscher',
#   'werkt',
#   'samen',
#   'link',
#   'leveamsterdam'],
#  ['rotterdam', 'uitsluiten_vanwege', 'racisme', 'steeds_maffer', 'echt'],
#  ['demoniseer',
#   'extra_klapvee',
# ...
#   'schie',
#   'donorwet',
#   'eerst'],
#  ['gewone_thuiszorger',
#   'amsterdam',
#   'vertrekken',
#   'beleid_kabinet',
#   'sociale_huurwoningen',
#   'word'],
#  ['gewone_thuiszorger',
#   'amsterdam',
#   'vertrekken',
#   'beleid_kabinet',
#   'sociale_huurwoningen',
#   'word'],
#  ['rtlnieuws',
#   'net',
#   'anglicisme',
#   'wit',
#   'blank',
#   'gebruikt',
#   'beticht',
#   'racisme'],
#  ['fipronil',
#   'vervuilde',
#   'mest',
#   'aangelengd',
#   'schone',
#   'mest',
#   'uitrijden',
#   'land',
#   'verhoudt',
#   'onlangs',
#   'on'],
#  ['demoniseer',
#   'extra_klapvee',
#   'helpen_tevergeefs',
#   'baudet',
#   'maakt',
#   'duidelijk',
#   'ruimte',
#   'rac'],
#  ['verschil', 'groen', 'gl', 'groen'],
#  ['ongelooflijk', 'enge', 'figuur', 'lu'],
#  ['ramautarsing', 'interview', 'politieke', 'partij', 'paragraaf'],
#  ['granaat', 'vvd', 'kamerlid', 'haga_bedreigt', 'voortbestaan_kabinet'],
#  ['rutte', 'vvd', 'steunt', 'rutte', 'neemt', 'maat', 'racis'],
#  ['haagse', 'politieke', 'cultuur', 'opzij', 'geduid', 'vuile'],
#  ['ras', 'klaver'],
#  ['ascher',
#   'vorig',
#   'kabinet',
#   'sodemieter',
#   'geholpen',
#   'gebrek',
#   'grote',
#   'mui'],
#  ['number',
#   'lijst',
#   'kies',
#   'duurzame_leefomgeving',
#   'schone',
#   'scholen',
#   'uitstoot'],
#  ['gaat', 'samenwerken', 'verschillen', 'nauwelijks', 'vraag'],
#  ['heel',
#   'mooi_nieuws',
#   'juf_ank',
#   'leraren',
#   'kabinet',
#   'begint',
#   'verlagen',
#   'werkdruk_strijdt',
#   'jaren'],
#  ['openbaar_vervoer',
#   'snel',
#   'betaalbaar',
#   'sp_knokt',
#   'behoud',
#   'metrolijnen_terwijl',
#   'kabinet',
#   'btw',
#   'kaartje'],
#  ['jacqueline',
#   'sweerts',
#   'nr',
#   'lijst',
#   'kies',
#   'aantrekkelijk',
#   'betere',
#   'zorg',
#   'oude'],
#  ['zwetskoning',
#   'baudet',
#   'discrimineert',
#   'basis',
#   'geloof_geslacht',
#   'geaardheid',
#   'ras'],
#  ['demoniseer',
#   'extra_klapvee',
#   'helpen_tevergeefs',
#   'baudet',
#   'maakt',
#   'duidelijk',
#   'ruimte',
#   'rac'],
#  ['rtlnieuws',
#   'net',
#   'anglicisme',
#   'wit',
#   'blank',
#   'gebruikt',
#   'beticht',
#   'racisme',
#   'woor'],
#  ['demoniseer',
#   'extra_klapvee',
#   'helpen_tevergeefs',
#   'baudet',
#   'maakt',
#   'duidelijk',
#   'ruimte',
#   'rac'],
#  ['baudet',
#   'houdt',
#   'prima',
#   'stand',
#   'roddel',
#   'persinterview',
#   'vermeend_racisme',
#   'vragen',
#   'neemt',
#   'afs'],
#  ['duidelijk', 'standpunten', 'desastreus', 'open', 'havenstad', 'rotterdam'],
#  ['rutte', 'vvd', 'steunt', 'rutte', 'neemt', 'maat', 'racis'],
#  ['freaky',
#   'way',
#   'weet',
#   'schiphol',
#   'ras',
#   'brengen',
#   'freaky',
#   'opmerking'],
#  ['pechtold',
#   'uitnodiging',
#   'asscher',
#   'werkt',
#   'samen',
#   'link',
#   'leveamsterdam'],
#  ['jinek',
#   'nooit',
#   'laten_horen',
#   'stemde',
#   'geeft',
#   'echte',
#   'bedenkingen',
#   'partij',
#   'ht'],
#  ['molukse', 'ouders', 'moesten', 'deel', 'kinderen', 'achterlaten'],
#  ['aantrekken',
#   'economie',
#   'woningmarkt',
#   'gemeente',
#   'financieel',
#   'helpen',
#   'pleit_ervoor',
#   'financiele',
#   'ruimte',
#   'word'],
#  ['lees', 'volledige_interview', 'oordeel'],
#  ['duivels_arrogant',
#   'productieve_eenzame',
#   'ouderen_euthaniseren',
#   'organen_roven',
#   'privacy_stelen',
#   'sleepw'],
#  ['inhoudelijk', 'bespraken', 'buma', 'uitstekend', 'mensen', 'tege'],
#  ['heel',
#   'mooi_nieuws',
#   'juf_ank',
#   'leraren',
#   'kabinet',
#   'begint',
#   'verlagen',
#   'werkdruk_strijdt',
#   'jaren'],
#  ['lees', 'volledige_interview', 'oordeel'],
#  ['debat', 'waar'],
#  ['nederlands_bekendste',
#   'droogkloot_marcel',
#   'roosmalen_sloopt',
#   'helemaal',
#   'moeder_luister',
#   'topper'],
#  ['alleen',
#   'ollongren',
#   'rutte',
#   'kennelijk_enig',
#   'benul',
#   'staatsrecht',
#   'minister',
#   'minister',
#   'ee'],
#  ['jr',
#   'verrassen',
#   'vrijdags',
#   'valentijnsdag',
#   'mensen',
#   'lokaal',
#   'verschil',
#   'maken',
#   'taart',
#   'nwim',
#   'heine',
#   'rijp',
#   'nk'],
#  ['jammer',
#   'groen',
#   'stad',
#   'daarbij',
#   'vergeten',
#   'steeds_verder',
#   'nauw',
#   'gekomen'],
#  ['alleen',
#   'ollongren',
#   'rutte',
#   'kennelijk_enig',
#   'benul',
#   'staatsrecht',
#   'minister',
#   'minister',
#   'ee'],
#  ['alleen',
#   'ollongren',
#   'rutte',
#   'kennelijk_enig',
#   'benul',
#   'staatsrecht',
#   'minister',
#   'minister',
#   'ee'],
#  ['weet',
#   'aandacht',
#   'makkelijk',
#   'leiden',
#   'pechtoldgate',
#   'dank',
#   'ruggegraatloze',
#   'msm'],
#  ['waarom',
#   'kijken',
#   'opeens',
#   'onderwijs',
#   'scores',
#   'allochtonen',
#   'heer',
#   'duk',
#   'verdienste'],
#  ['komen',
#   'volgend_jaar',
#   'gezinnen',
#   'engeland',
#   'kabinet',
#   'gevraagd',
#   'woningen'],
#  ['leefbaar_rotterdam',
#   'cda',
#   'campagneleider',
#   'vreemde',
#   'spreuken',
#   'borden',
#   'lijken',
#   'wel',
#   'bijzond'],
#  ['mooi',
#   'verhaal',
#   'joris',
#   'luyendijk',
#   'docentendag',
#   'online',
#   'project',
#   'correspobdent',
#   'pvvers',
#   'toena'],
#  ['hallo_nl',
#   'media',
#   'fvd',
#   'doet',
#   'gemeente',
#   'mee',
#   'mag',
#   'gewoon',
#   'weer',
#   'detailhandel_werk'],
#  ['nou',
#   'technisch',
#   'gezien',
#   'werkt',
#   'leefbaar',
#   'alleen',
#   'verkiezingen',
#   'samen',
#   'fvd'],
#  ['partijkartel', 'helemaal', 'open_discussie', 'partijkartel', 'lynchpartij'],
#  ['vand_helmond',
#   'ruim_baan',
#   'kleinschalige',
#   'grootschalige',
#   'opwek',
#   'duurzame_energie',
#   'gemeente',
#   'neemt'],
#  ['zeg', 'manfred', 'vragen', 'mag', 'loop', 'demonstratie', 'racisme'],
#  ['doe', 'normaal', 'stem', 'vooral', 'lokaal'],
#  ['kabinetsreactie',
#   'initiatiefnota',
#   'nonverstandig_kabinet',
#   'gaat',
#   'mee',
#   'voorstellen',
#   'priva'],
#  ['pvda',
#   'gaan',
#   'discriminatie',
#   'lhbti',
#   'community',
#   'aanpakken',
#   'boot',
#   'gaypride',
#   'denkamsterdam'],
#  ['alleen',
#   'ollongren',
#   'rutte',
#   'kennelijk_enig',
#   'benul',
#   'staatsrecht',
#   'minister',
#   'minister',
#   'ee'],
#  ['rotterdam', 'uitsluiten_vanwege', 'racisme', 'steeds_maffer', 'echt'],
#  ['demoniseer',
#   'extra_klapvee',
#   'helpen_tevergeefs',
#   'baudet',
#   'maakt',
#   'duidelijk',
#   'ruimte',
#   'rac'],
#  ['coalitieruzie',
#   'minister',
#   'ollongren',
#   'woordvoerder',
#   'rutte',
#   'pechtold'],
#  ['alleen',
#   'ollongren',
#   'rutte',
#   'kennelijk_enig',
#   'benul',
#   'staatsrecht',
#   'minister',
#   'minister',
#   'ee'],
#  ['hallo_nl',
#   'media',
#   'fvd',
#   'doet',
#   'gemeente',
#   'mee',
#   'mag',
#   'gewoon',
#   'weer',
#   'detailhandel_werk',
#   'veil'],
#  ['wahahaha_pechtold',
#   'leefbaar_rotterdam',
#   'vier_jaar',
#   'geleden',
#   'gewone',
#   'partij',
#   'discrimineerde_hahaha',
#   'leveams'],
#  ['pechtold',
#   'uitnodiging',
#   'asscher',
#   'werkt',
#   'samen',
#   'link',
#   'leveamsterdam'],
#  ['heel',
#   'mooi_nieuws',
#   'juf_ank',
#   'leraren',
#   'kabinet',
#   'begint',
#   'verlagen',
#   'werkdruk_strijdt',
#   'jaren'],
#  ['denk', 'policorleiders', 'dieptepunt_qua', 'bereikt', 'pechtold', 'klaver'],
#  ['kabinetsreactie',
#   'initiatiefnota',
#   'nonverstandig_kabinet',
#   'gaat',
#   'mee',
#   'voorstellen',
#   'priva'],
#  ['alleen',
#   'ollongren',
#   'rutte',
#   'kennelijk_enig',
#   'benul',
#   'staatsrecht',
#   'minister',
#   'minister',
#   'ee'],
#  ['lees', 'volledige_interview', 'oordeel'],
#  ['pechtold',
#   'mening',
#   'veranderen',
#   'referendum',
#   'mensen',
#   'stemmen',
#   'pas',
#   'eng'],
#  ['partijkartel', 'helemaal', 'open_discussie', 'partijkartel', 'lynchpartij'],
#  ['partijkartel', 'langer', 'politiek', 'schakelen', 'koste', 'kost'],
#  ['mond_vol', 'populisme'],
#  ['laatste', 'keer', 'hebt', 'einde', 'verhit'],
#  ['vind', 'helemaal', 'reageren', 'kletspraat', 'racisme', 'frame'],
#  ['campagneplan',
#   'inmiddels',
#   'wel',
#   'duidelijk',
#   'inhoudelijk',
#   'valt',
#   'positiefs',
#   'melden'],
#  ['opmerkelijker',
#   'pvda',
#   'vindt',
#   'aanwezigheid',
#   'malediven',
#   'belangrijker',
#   'debat'],
#  ['vandaag',
#   'jaar_geleden',
#   'pvda',
#   'opgericht',
#   'daarom',
#   'blikken',
#   'terug',
#   'interview',
#   'maarten',
#   'begin'],
#  ['denkt',
#   'wel',
#   'hoop',
#   'ontzettend',
#   'zootje',
#   'rutteiii',
#   'helemaal',
#   'weggevaagd'],
#  ['landelijk', 'regelen', 'lokaal'],
#  ['denk',
#   'policorleiders',
#   'dieptepunt_qua',
#   'bereikt',
#   'pechtold',
#   'klaver',
#   'asscher'],
#  ['bnr',
#   'gaat',
#   'lekker',
#   'spin',
#   'echte',
#   'zzp_ers',
#   'opdrachtgevers_ervaren',
#   'heel',
#   'anders',
#   'namelijk'],
#  ['gewone_thuiszorger',
#   'amsterdam',
#   'vertrekken',
#   'beleid_kabinet',
#   'sociale_huurwoningen',
#   'word'],
#  ['terzijde_waarom',
#   'leveamsterdam_nationaal',
#   'vragen',
#   'zagen',
#   'wel',
#   'vlerk',
#   'maat'],
#  ['doodsbang', 'daarom'],
#  ['politiek',
#   'nl',
#   'eindelijk',
#   'inzien',
#   'tegenstem',
#   'vraagt',
#   'serieuze',
#   'herziening',
#   'verbetering',
#   'voors'],
#  ['vind', 'helemaal', 'reageren', 'kletspraat', 'racisme', 'frame'],
#  ['bull', 'shit', 'luisteren', 'vaak', 'baudet', 'zeggen', 'racisme'],
#  ['wahahaha_pechtold',
#   'leefbaar_rotterdam',
#   'vier_jaar',
#   'geleden',
#   'gewone',
#   'partij',
#   'discrimineerde_hahaha',
#   'leveams'],
#  ['echt', 'gemeente', 'onwaardig', 'hoezo', 'wegzetten'],
#  ['heel',
#   'mooi_nieuws',
#   'juf_ank',
#   'leraren',
#   'kabinet',
#   'begint',
#   'verlagen',
#   'werkdruk_strijdt',
#   'jaren'],
#  ['vind', 'helemaal', 'reageren', 'kletspraat', 'racisme', 'frame'],
#  ['spoor',
#   'echt',
#   'kwijt',
#   'goede',
#   'ideeen',
#   'hebt',
#   'misschien',
#   'gewoon',
#   'idee',
#   'hebt',
#   'kun'],
#  ['lijsttrekkers',
#   'vallen',
#   'baudet',
#   'racisme',
#   'moeten',
#   'arrogantie',
#   'slopen'],
#  ['mooi_resultaat', 'samenwerken_loont'],
#  ['gemeente', 'godsnaam', 'schuld', 'opbouwen'],
#  ['gelijk',
#   'trekken',
#   'lonen',
#   'basisschool',
#   'leerkrachten',
#   'leerkrachten',
#   'voortgezet',
#   'onderwi'],
#  ['alleen',
#   'ollongren',
#   'rutte',
#   'kennelijk_enig',
#   'benul',
#   'staatsrecht',
#   'minister',
#   'minister',
#   'ee'],
#  ['gedreven', 'persoonlijke_rancune', 'mag', 'journalistiek_bedrijven'],
#  ['zielig', 'gedoe', 'baudet', 'voren', 'bedacht', 'ingestudeerd'],
#  [],
#  ['gewone_thuiszorger',
#   'amsterdam',
#   'vertrekken',
#   'beleid_kabinet',
#   'sociale_huurwoningen',
#   'word'],
#  ['geachte_heer', 'anders_verwacht'],
#  ['gedreven', 'persoonlijke_rancune', 'mag', 'journalistiek_bedrijven'],
#  ['leider',
#   'kabinet',
#   'amsterdam',
#   'helpen',
#   'btw',
#   'verhogen',
#   'kaartjes',
#   'openbaar_vervoer'],
#  ['zelfs', 'kantoor', 'denk', 'kleurt', 'leefbaar_rotterdam', 'denachtvanlr'],
#  ['ha',
#   'stemmer',
#   'hebt',
#   'goed',
#   'geweerd',
#   'vanavond',
#   'aanklacht',
#   'racisme',
#   'lan'],
#  ['demoniseer',
#   'extra_klapvee',
#   'helpen_tevergeefs',
#   'baudet',
#   'maakt',
#   'duidelijk',
#   'ruimte',
#   'rac'],
#  ['amsterdam',
#   'lijsttrekkers',
#   'vallen',
#   'baudet',
#   'racisme',
#   'forum',
#   'democratie',
#   'leider'],
#  ['gewone_thuiszorger',
#   'amsterdam',
#   'vertrekken',
#   'beleid_kabinet',
#   'sociale_huurwoningen',
#   'word'],
#  ['duivels_arrogant',
#   'productieve_eenzame',
#   'ouderen_euthaniseren',
#   'organen_roven',
#   'privacy_stelen',
#   'sleepw'],
#  ['gedreven', 'persoonlijke_rancune', 'mag', 'journalistiek_bedrijven'],
#  ['slechts', 'deel', 'eisen', 'team', 'stopt', 'stake'],
#  ['liberaal',
#   'netwerk',
#   'mobiliteit',
#   'leefomgeving',
#   'ism',
#   'thematisch',
#   'netwerk',
#   'energie',
#   'bijeenkomst',
#   'landelijk',
#   'gebie'],
#  ['man',
#   'lekker_edoch',
#   'eu',
#   'baas',
#   'vvd',
#   'weet',
#   'wel',
#   'eu_lovers',
#   'kabinet'],
#  ['jinek',
#   'nooit',
#   'laten_horen',
#   'stemde',
#   'geeft',
#   'echte',
#   'bedenkingen',
#   'partij',
#   'ht'],
#  ['justitie', 'nationaliteit'],
#  ['beetje', 'ongeloofwaardig', 'even', 'hiervoor', 'terugtrekt', 'comite'],
#  ['gedreven', 'persoonlijke_rancune', 'mag', 'journalistiek_bedrijven'],
#  ['kom',
#   'argumenten',
#   'zielige',
#   'racist',
#   'kaart',
#   'compleet',
#   'goed',
#   'partij'],
#  ['alleen',
#   'ollongren',
#   'rutte',
#   'kennelijk_enig',
#   'benul',
#   'staatsrecht',
#   'minister',
#   'minister',
#   'ee'],
#  ['mooi', 'slechts', 'deel', 'eisen', 'lonen', 'gaan', 'omho'],
#  ['gedreven', 'persoonlijke_rancune', 'mag', 'journalistiek_bedrijven'],
#  ['nieuw',
#   'opgezet',
#   'zorgintensief',
#   'klasje',
#   'volproppen',
#   'klein',
#   'lokaal'],
#  ['integraties',
#   'racisme',
#   'bla_bla',
#   'hebt',
#   'grote_bek',
#   'partij',
#   'vol',
#   'zit',
#   'racisten',
#   'pro',
#   'islam'],
#  ['pechtold', 'sluit_leefbaar', 'rotterdam', 'baudet'],
#  ['rotterdam', 'uitsluiten_vanwege', 'racisme', 'steeds_maffer', 'echt'],
#  ['partijkartel', 'langer', 'politiek', 'schakelen', 'koste', 'kost'],
#  ['daarom', 'beter', 'lokaal', 'stemmen'],
#  ['rotterdamse', 'ers', 'bedenken', 'raad'],
#  ['zegt',
#   'onderwijs',
#   'komen',
#   'geeft',
#   'merkwaardig',
#   'signaal',
#   'systematisch',
#   'lid'],
#  ['raadgevend_referendum', 'zeker', 'politiek', 'uitslag'],
#  ['doodsbang', 'daarom'],
#  ['zorgelijk', 'kand', 'raadslid', 'dam', 'homosexualiteit'],
#  ['terzijde_waarom',
#   'leveamsterdam_nationaal',
#   'vragen',
#   'zagen',
#   'wel',
#   'vlerk',
#   'maat'],
#  ['racisme',
#   'debat',
#   'balie',
#   'mens',
#   'kleur',
#   'podium',
#   'gejorist',
#   'schande',
#   'jinek'],
#  ['alleen',
#   'ollongren',
#   'rutte',
#   'kennelijk_enig',
#   'benul',
#   'staatsrecht',
#   'minister',
#   'minister',
#   'ee'],
#  ['los',
#   'morgen',
#   'rotterdam_ontwaken',
#   'leefbaar_rotterdam',
#   'nachtvanlr',
#   'gr'],
#  ['pechtold',
#   'keer',
#   'keer',
#   'feiten_verdraait',
#   'begint_gevaarlijke',
#   'vormen'],
#  ['nr',
#   'ramautarsing',
#   'amsterdam',
#   'tweet',
#   'racisme',
#   'nr',
#   'oh',
#   'beschaafde',
#   'annabelnanninga',
#   'retweet'],
#  ['gedreven', 'persoonlijke_rancune', 'mag', 'journalistiek_bedrijven'],
#  ['vandaag',
#   'zit',
#   'kabinet',
#   'precies',
#   'dagen',
#   'land',
#   'willen',
#   'geven',
#   'cda'],
#  ['molukse', 'ouders', 'moesten', 'deel', 'kinderen', 'achterlaten'],
#  ['doe', 'normaal', 'stem', 'vooral', 'lokaal'],
#  ['nacht', 'leefbaar_rotterdam', 'nachtvanlr'],
#  ['donorwet',
#   'homo',
#   'mag',
#   'bloed',
#   'geven',
#   'wel',
#   'automatisch_donor',
#   'best',
#   'gek',
#   'uitleggen'],
#  ['demoniseer',
#   'extra_klapvee',
#   'helpen_tevergeefs',
#   'baudet',
#   'maakt',
#   'duidelijk',
#   'ruimte',
#   'rac'],
#  ['constante_attack', 'uitspraak', 'context_gehaald', 'groep', 'rassenobses'],
#  ['zelfs', 'kantoor', 'denk', 'kleurt', 'leefbaar_rotterdam', 'denachtvanlr'],
#  ['rotterdam', 'uitsluiten_vanwege', 'racisme', 'steeds_maffer', 'echt'],
#  ['los',
#   'morgen',
#   'rotterdam_ontwaken',
#   'leefbaar_rotterdam',
#   'nachtvanlr',
#   'gr'],
#  ['pechtold',
#   'sluit_leefbaar',
#   'rotterdam',
#   'baudet',
#   'sluit',
#   'toekomstige',
#   'coal'],
#  ['gemeente', 'raad', 'fvdamsterdamnee_fvdamsterdamnee', 'fvdamsterdamnee'],
#  ['ongelofelijk', 'demonstratie', 'organiseren', 'racisme'],
#  ['nooit', 'walgelijks', 'gezien', 'ophitsing', 'partijen', 'wetenschappe'],
#  ['rotterdam', 'uitsluiten_vanwege', 'racisme', 'steeds_maffer', 'echt'],
#  ['verlichting', 'erasmusbrug', 'aangepast', 'nacht', 'leefbaar_rotterdam'],
#  ['demoniseer',
#   'extra_klapvee',
#   'helpen_tevergeefs',
#   'baudet',
#   'maakt',
#   'duidelijk',
#   'ruimte',
#   'rac'],
#  ['heel',
#   'mooi_nieuws',
#   'juf_ank',
#   'leraren',
#   'kabinet',
#   'begint',
#   'verlagen',
#   'werkdruk_strijdt',
#   'jaren'],
#  ['nederlands_bekendste',
#   'droogkloot_marcel',
#   'roosmalen_sloopt',
#   'helemaal',
#   'moeder_luister',
#   'topper'],
#  ['doodsbang', 'daarom'],
#  ['mannetje',
#   'gratis',
#   'omkoop',
#   'appartement',
#   'lagere',
#   'partijtje',
#   'dwangmatig'],
#  ['bull', 'shit', 'luisteren', 'vaak', 'baudet', 'zeggen', 'racisme'],
#  ['verlichting', 'erasmusbrug', 'aangepast', 'nacht', 'leefbaar_rotterdam'],
#  ['kijk'],
#  ['pechtold', 'sluit_leefbaar', 'rotterdam', 'baudet'],
#  ['gemeente', 'geeft', 'geheim', 'kiezer', 'afgerekend_ton'],
#  ['rotterdam', 'uitsluiten_vanwege', 'racisme', 'steeds_maffer', 'echt'],
#  ['scholieren_demonstreerden',
#   'ideeen',
#   'centrum',
#   'democraten_terechte',
#   'zorgen',
#   'racistische',
#   'ideeen',
#   'fvd'],
#  ['duivels_arrogant',
#   'productieve_eenzame',
#   'ouderen_euthaniseren',
#   'organen_roven',
#   'privacy_stelen',
#   'sleepw'],
#  ['vreemd', 'standpunt', 'steeds_innig', 'samenwerken', 'coalitie', 'vorm'],
#  ['scholieren_demonstreerden',
#   'ideeen',
#   'centrum',
#   'democraten_terechte',
#   'zorgen',
#   'racistische',
#   'ideeen',
#   'fvd',
#   'http'],
#  ['leefbaar_rotterdam',
#   'zegt',
#   'veiligheid',
#   'regels',
#   'handhaven',
#   'doe',
#   'illegaa'],
#  ['alleen',
#   'ollongren',
#   'rutte',
#   'kennelijk_enig',
#   'benul',
#   'staatsrecht',
#   'minister',
#   'minister',
#   'ee'],
#  ['kijk', 'online_formulier', 'referendum_aflosboete', 'tweet', 'wilt'],
#  ...]

# %%
# Save results
with open('elections_data_lemmatized', 'wb') as fp:
    pickle.dump(data_lemmatized, fp)

# %%
# Load results
with open('elections_data_lemmatized', 'rb') as fp:
    data_lemmatized = pickle.load(fp)

# %%
import re, os, time
import numpy as np
import pandas as pd
from pprint import pprint

# Gensim
from gensim.models.ldamodel import LdaModel
from gensim.models import Phrases
from gensim.models.phrases import Phraser
import gensim.corpora as corpora
from gensim.utils import simple_preprocess
from gensim.models import CoherenceModel

# Import nltk stopwords and spacy for lemmatization
from nltk.corpus import stopwords
from nltk.tokenize import WordPunctTokenizer

# Plotting tools
import pyLDAvis
import pyLDAvis.gensim  # don't skip this
import matplotlib.pyplot as plt
import spacy
# %matplotlib inline

# Enable logging for Gensim - optional
import logging
logging.basicConfig(format='%(asctime)s : %(levelname)s : %(message)s', level=logging.ERROR)

import warnings
warnings.filterwarnings('ignore',category=DeprecationWarning)

import time
import pickle
import bs4

# Collect names of Tweet files
from os import listdir
from os.path import isfile, join
import json

# Plotting tools
import pyLDAvis
import pyLDAvis.sklearn
import matplotlib.pyplot as plt
import textacy
from gensim.models.doc2vec import Doc2Vec, TaggedDocument
from bokeh.charts import Chord

from ipysankeywidget import SankeyWidget
from ipywidgets import Layout
from IPython.display import display

from pysankey import sankey

# %%
# Document training with doc2vec

# Tag each tweets 
documents = [TaggedDocument(doc, [i]) for i, doc in enumerate(data_lemmatized)]

# Train documents(tweets) with doc2vec library
model = Doc2Vec(documents, vector_size=300, window_size = 15, min_count=1, epochs=150, 
                sampling_threshold = 1e-5,negative_size = 5, 
                workers=32,train_epoch = 150, dm = 0) #0 = dbow; 1 = dmpv 

# Save the training set model for further use
model.save("d2v.model")

# %% [markdown]
# #### 6. Create the Dictionary and Corpus needed for Topic Modeling

# %%
# Create Dictionary
dictionary = corpora.Dictionary(data_lemmatized)

# Filter out words that occur less than 20 documents, or more than 50% of the documents
# dictionary.filter_extremes(no_below=20, no_above=0.5)

# Create Corpus
texts = data_lemmatized

# Term Document Frequency
corpus = [dictionary.doc2bow(text) for text in texts]

# Corpus contains pairs - a unique id for each word in the document and its frequency (word_id, word_frequency).
print(pd.DataFrame(corpus[:1]))

# %%
# We also can check what was the word from the dictionary - dictionary
pprint(corpus[:1])
print(dictionary[0])

# %%
# Readable format
[[(dictionary[id], freq) for id, freq in cp] for cp in corpus[:1]]

# %%
print('Number of unique tokens (words + bigrams + trigrams): %d' % len(dictionary))
print('Number of documents: %d' % len(corpus))

# %% [markdown]
# #### 7. Build the model

# %%
# # Build Gensim LDA model
# start = time.time()
# lda_model = gensim.models.ldamodel.LdaModel(corpus=corpus, # corpus
#                                            dictionary=dictionary, # dict
#                                            num_topics=10, # number of topic to be extracted
#                                            random_state=100,
#                                            update_every=1, #
#                                            chunksize=100, # 
#                                            passes=10, # 
#                                            alpha='auto', # 
#                                            per_word_topics=True) # 
# end = time.time()
# print('Algorithm time =', round((end-start)/60), 'min')

# %%
# Gensim LDA with Multiprocessing
from gensim.models import LdaMulticore

num_topics = 10
chunksize = 100
passes = 10
# %time lda_model = LdaMulticore(corpus=corpus, \
                       id2word=dictionary.id2token, \
                       num_topics=num_topics, \
                       random_state=100, \
                       chunksize=chunksize, \
                       passes=passes, \
                       per_word_topics=True)

# %%
# Save the model for further usage
from gensim.test.utils import datapath
temp_file = datapath('lda_model_300k') 
lda_model.save(temp_file)

# %%
# Load a potentially pretrained model
from gensim.test.utils import datapath
temp_file = datapath('lda_model_300k') 
lda_model = LdaModel.load(temp_file)

# %% [markdown]
# #### 8. Print the topics

# %%
# Print one topic
lda_model.show_topic(0)

# %%
# Print all topics
pprint(lda_model.print_topics())
doc_lda = lda_model[corpus]

# %% [markdown]
# #### 9. Compute Model Perplexity and Coherence Score

# %% [markdown]
# To measure perfomance there are two metrics: perplexity and coherence score.

# %%
# Compute Perplexity
print('\nPerplexity: ', lda_model.log_perplexity(corpus))  # a measure of how good the model is. lower the better.

# Compute Coherence Scores
coherence_model_lda = CoherenceModel(model=lda_model, texts=data_lemmatized, dictionary=dictionary, coherence='c_v')
coherence_lda = coherence_model_lda.get_coherence()
print('\nCoherence Score c_v measure: ', coherence_lda)

coherence_model_lda = CoherenceModel(model=lda_model, texts=data_lemmatized, dictionary=dictionary, coherence='u_mass')
coherence_lda = coherence_model_lda.get_coherence()
print('\nCoherence Score UMass measure: ', coherence_lda)

# %%
def compute_coherence_values(dictionary, corpus, texts, limit, start=2, step=3):
    """
    Compute c_v coherence for various number of topics

    Parameters:
    ----------
    dictionary : Gensim dictionary
    corpus : Gensim corpus
    texts : List of input texts
    limit : Max num of topics

    Returns:
    -------
    model_list : List of LDA topic models
    coherence_values : Coherence values corresponding to the LDA model with respective number of topics
    """
    coherence_values = []
    model_list = []
    for num_topics in range(start, limit, step):
        model=LdaMulticore(corpus=corpus, 
                       id2word=dictionary, 
                       num_topics=num_topics, 
                       random_state=100,
                       chunksize=chunksize, 
                       passes=passes,
                       per_word_topics=True)
        print('Model with', num_topics, 'topics done')
        model_list.append(model)
        coherencemodel = CoherenceModel(model=model, texts=texts, dictionary=dictionary, coherence='c_v')
        coherence_values.append(coherencemodel.get_coherence())

    return model_list, coherence_values

# %%
start = 3
limit = 20
step = 1
model_list, coherence_values = compute_coherence_values(dictionary=dictionary, corpus=corpus, texts=data_lemmatized, start=start, limit=limit, step=step)

# Show graph
import matplotlib.pyplot as plt
limit=limit; start=start; step=step;
x = range(start, limit, step)
plt.plot(x, coherence_values)
plt.xlabel("Num Topics")
plt.ylabel("Coherence score")
plt.legend(("coherence_values"), loc='best')
plt.show()

# %%
# We can decrease the number of words per topic and show them separately

topn = 10 # to keep it readable
top_topics = lda_model.top_topics(corpus=corpus, dictionary=dictionary, topn=topn)

# Average topic coherence is the sum of topic coherences of all topics, divided by the number of topics.
avg_topic_coherence = sum([t[1] for t in top_topics]) / num_topics
print('Average topic coherence: %.4f.' % avg_topic_coherence)

pprint(top_topics)

# %% [markdown]
# #### 10. Visualize topics-keywords

# %% [markdown]
# Each bubble is a topic. The larger the bubble, the more prevalent the topic.

# %%
# Visualize the topics
pyLDAvis.enable_notebook()
vis = pyLDAvis.gensim.prepare(lda_model, corpus, dictionary)
vis
